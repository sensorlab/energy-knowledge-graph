# %%
import pandas as pd

import numpy as np
from tqdm.notebook import tqdm
import pickle

# %%
save_path = "./Energy_graph/data/processed_watts/cleaned/"
read_path = "./Energy_graph/data/processed_watts/old/"

# %%
def HES_remove():
    print("HES: ")
    df = pd.read_pickle(read_path+"HES.pkl")
    for h in df:
        keys = list(df[h].keys())
        for k in keys:
            if "sockets" in k or "light" in k or "heat" in k or "outlet" in k or "lamp" in k:
                print("REMOVE: ", k)
                del df[h][k]
            
    
    df["HES_1"].keys()


    # save to pickle
    with open(save_path +"HES_clean.pkl", 'wb') as handle:
        pickle.dump(df, handle, protocol=pickle.HIGHEST_PROTOCOL)

    print("*************************************************************")

def REDD_remove():
    print("REDD: ")
    df = pd.read_pickle(read_path +"REDD.pkl")
    for h in df:
        keys = list(df[h].keys())
        for k in keys:
            if "sockets" in k or "light" in k or "CE appliance" in k or "subpanel" in k or "air handling unit" in k:
                print("REMOVE: ", k)
                del df[h][k]
            # print(k)
    
    # df["HES_1"].keys()


    # save to pickle
    with open(save_path+"REDD_clean.pkl", 'wb') as handle:
        pickle.dump(df, handle, protocol=pickle.HIGHEST_PROTOCOL)

    print("*************************************************************")


def ECO_remove():
    print("ECO: ")
    df = pd.read_pickle(read_path+"ECO.pkl")
    for h in df:
        keys = list(df[h].keys())
        for k in keys:
            if "Lamp" in k or "light" in k or "CE appliance" in k or "subpanel" in k or "Tablet" in k:
                print("REMOVE: ", k)
                del df[h][k]
            # print(k)
    
    # df["HES_1"].keys()


    # save to pickle
    with open(save_path+"ECO_clean.pkl", 'wb') as handle:
        pickle.dump(df, handle, protocol=pickle.HIGHEST_PROTOCOL)

    print("*************************************************************")

def UKDALE_remove():
    print("UKDALE: ")
    df = pd.read_pickle(read_path+"/UK-DALE.pkl")
    for h in df:
        # if h == "UKDALE_1":
        #     print("skip", h) 
        #     continue
        keys = list(df[h].keys())
        for k in keys:
            if "set top box" in k or "light" in k or "plug" in k or "lamp" in k  or "charger" in k or "USB" in k or "radio" in k or "baby" in k or "bouncy castle pump" in k or "solar thermal pumping station" in k or "external hard disk" in k:
                print("REMOVE: ", k)
                del df[h][k]
            
            # print(k)
    
    # df["HES_1"].keys()


    # save to pickle
    with open(save_path+"UKDALE_clean.pkl", 'wb') as handle:
        pickle.dump(df, handle, protocol=pickle.HIGHEST_PROTOCOL)

    print("*************************************************************")

def REFIT_remove():
    print("REFIT: ")
    df = pd.read_pickle(read_path+"REFIT.pkl")
    for h in df:
        keys = list(df[h].keys())
        for k in keys:
            if "kettle/toaster" in k or "dehumidifier/heater" in k or "plug" in k or "lamp" in k or "vivarium" in k or "oven extractor fan" in k:
                print("REMOVE: ", k)
                del df[h][k]
            # print(k)
    
    # df["HES_1"].keys()


    # save to pickle
    with open(save_path+"REFIT_clean.pkl", 'wb') as handle:
        pickle.dump(df, handle, protocol=pickle.HIGHEST_PROTOCOL)

    print("*************************************************************")

def SUST2_remove():
    print("SUST2: ")
    df = pd.read_pickle(read_path+"SUST2.pkl")
    for h in df:
        keys = list(df[h].keys())
        for k in keys:
            if "HairDryer-Straightener" in k or "dehumidifier/heater" in k or "plug" in k or "lamp" in k:
                print("REMOVE: ", k)
                del df[h][k]
            # print(k)
    
    # df["HES_1"].keys()


    # save to pickle
    with open(save_path+"SUST2_clean.pkl", 'wb') as handle:
        pickle.dump(df, handle, protocol=pickle.HIGHEST_PROTOCOL)

    print("*************************************************************")

def DEDDIAG_remove():
    print("DEDDIAG: ")
    df = pd.read_pickle(read_path+"DEDDIAG.pkl")
    for h in df:
        keys = list(df[h].keys())
        for k in keys:
            if "Office Desk" in k or "dehumidifier/heater" in k or "plug" in k or "lamp" in k:
                print("REMOVE: ", k)
                del df[h][k]
            # print(k)
    
    # df["HES_1"].keys()


    # save to pickle
    with open(save_path+"DEDDIAG_clean.pkl", 'wb') as handle:
        pickle.dump(df, handle, protocol=pickle.HIGHEST_PROTOCOL)

    print("*************************************************************")

def HEART_remove():
    print("HEART: ")
    df = pd.read_pickle(read_path+"HEART.pkl")
    for h in df:
        keys = list(df[h].keys())
        for k in keys:
            if "Office Desk" in k or "dehumidifier/heater" in k or "plug" in k or "lamp" in k or "radio" in k:
                print("REMOVE: ", k)
                del df[h][k]
            # print(k)
    
    # df["HES_1"].keys()


    # save to pickle
    with open(save_path+"HEART_clean.pkl", 'wb') as handle:
        pickle.dump(df, handle, protocol=pickle.HIGHEST_PROTOCOL)

    print("*************************************************************")

def IAWE_remove():
    print("IAWE:")
    df = pd.read_pickle(read_path+"IAWE.pkl")
    for h in df:
        keys = list(df[h].keys())
        for k in keys:
            if "wet appliance" in k or "dehumidifier/heater" in k or "plug" in k or "lamp" in k or "motor" in k:
                print("REMOVE: ", k)
                del df[h][k]
            # print(k)
    
    # df["HES_1"].keys()


    # save to pickle
    with open(save_path+"IAWE_clean.pkl", 'wb') as handle:
        pickle.dump(df, handle, protocol=pickle.HIGHEST_PROTOCOL)
    print("*************************************************************")

def DRED_remove():
    print("DRED:")
    df = pd.read_pickle(read_path+"DRED.pkl")
    for h in df:
        keys = list(df[h].keys())
        for k in keys:
            if "sockets" in k or "dehumidifier/heater" in k or "plug" in k or "lamp" in k:
                print("REMOVE: ", k)
                del df[h][k]
            # print(k)
    
    # df["HES_1"].keys()


    # save to pickle
    with open(save_path+"DRED_clean.pkl", 'wb') as handle:
        pickle.dump(df, handle, protocol=pickle.HIGHEST_PROTOCOL)

    print("*************************************************************")

functions = [HES_remove, REDD_remove, ECO_remove, UKDALE_remove, REFIT_remove, DEDDIAG_remove, HEART_remove, IAWE_remove, DRED_remove]

# %%
for f in functions:
    f()
# Out:
# HES:
# *************************************************************
# REDD:
# REMOVE:  sockets
# REMOVE:  light
# REMOVE:  sockets
# REMOVE:  light
# REMOVE:  sockets
# REMOVE:  light
# REMOVE:  CE appliance
# REMOVE:  light
# REMOVE:  sockets
# REMOVE:  light
# REMOVE:  sockets
# REMOVE:  subpanel
# REMOVE:  CE appliance
# REMOVE:  sockets
# REMOVE:  CE appliance
# REMOVE:  light
# REMOVE:  air handling unit
# *************************************************************
# ECO:
# REMOVE:  Lamp
# REMOVE:  Tablet
# REMOVE:  Lamp
# REMOVE:  Tablet
# REMOVE:  Tablet
# REMOVE:  Lamp
# REMOVE:  Tablet
# *************************************************************
# UKDALE:
# REMOVE:  set top box
# REMOVE:  external hard disk
# REMOVE:  light
# REMOVE:  tablet computer charger
# REMOVE:  radio
# REMOVE:  external hard disk
# REMOVE:  USB hub
# REMOVE:  baby monitor
# REMOVE:  mobile phone charger
# REMOVE:  bouncy castle pump
# REMOVE:  solar thermal pumping station
# REMOVE:  charger
# *************************************************************
# REFIT:
# REMOVE:   kettle/toaster
# REMOVE:   vivarium
# REMOVE:   dehumidifier/heater
# REMOVE:   plug site (bedroom)
# REMOVE:   lamp (80watts)
# REMOVE:   oven extractor fan
# *************************************************************
# DEDDIAG:
# REMOVE:  Office Desk
# *************************************************************
# HEART:
# REMOVE:  lamp
# REMOVE:  lamp
# REMOVE:  radio
# *************************************************************
# IAWE:
# REMOVE:  wet appliance
# REMOVE:  motor
# *************************************************************
# DRED:
# REMOVE:  sockets
# *************************************************************
