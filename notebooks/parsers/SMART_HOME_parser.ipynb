# %%
import pandas as pd
import os

# %%
# HomeA_df_2014 = pd.read_csv("./Energy_graph/data/raw/SMART_HOME/HomeA/2014/HomeA-meter2_2014.csv")
# HomeB_df_2015 = pd.read_csv("./Energy_graph/data/raw/SMART_HOME/HomeA/2015/HomeA-meter2_2015.csv")
# HomeC_df_2016 = pd.read_csv("./Energy_graph/data/raw/SMART_HOME/HomeA/2016/HomeA-meter2_2016.csv")




# print(HomeA_df_2014.columns.equals(HomeB_df_2015.columns))
# print(HomeB_df_2015.columns.equals(HomeC_df_2016.columns))

# # for house b
# HomeB_df_2014 = pd.read_csv("./Energy_graph/data/raw/SMART_HOME/HomeB/2014/HomeB-meter2_2014.csv")
# HomeB_df_2015 = pd.read_csv("./Energy_graph/data/raw/SMART_HOME/HomeB/2015/HomeB-meter2_2015.csv")
# HomeB_df_2016 = pd.read_csv("./Energy_graph/data/raw/SMART_HOME/HomeB/2016/HomeB-meter2_2016.csv")

# print(HomeB_df_2014.columns.equals(HomeB_df_2015.columns))
# print(HomeB_df_2015.columns.equals(HomeB_df_2016.columns))

# # for house c

# HomeC_df_2014 = pd.read_csv("./Energy_graph/data/raw/SMART_HOME/HomeC/2014/HomeC-meter2_2014.csv")
# HomeC_df_2015 = pd.read_csv("./Energy_graph/data/raw/SMART_HOME/HomeC/2015/HomeC-meter2_2015.csv")
# HomeC_df_2016 = pd.read_csv("./Energy_graph/data/raw/SMART_HOME/HomeC/2016/HomeC-meter2_2016.csv")

# print(HomeC_df_2014.columns.equals(HomeC_df_2015.columns))
# print(HomeC_df_2015.columns.equals(HomeC_df_2016.columns))


# # for house d

# # HomeD_df_2014 = pd.read_csv("./Energy_graph/data/raw/SMART_HOME/HomeD/2014/HomeD-meter2_2014.csv")
# HomeD_df_2015 = pd.read_csv("./Energy_graph/data/raw/SMART_HOME/HomeD/2015/HomeD-meter2_2015.csv")
# HomeD_df_2016 = pd.read_csv("./Energy_graph/data/raw/SMART_HOME/HomeD/2016/HomeD-meter2_2016.csv")

# # print(HomeD_df_2014.columns.equals(HomeD_df_2015.columns))
# print(HomeD_df_2015.columns.equals(HomeD_df_2016.columns))

# # for house f
# HomeF_df_2014 = pd.read_csv("./Energy_graph/data/raw/SMART_HOME/HomeF/2014/HomeF-meter2_2014.csv")
# HomeF_df_2015 = pd.read_csv("./Energy_graph/data/raw/SMART_HOME/HomeF/2015/HomeF-meter2_2015.csv")
# HomeF_df_2016 = pd.read_csv("./Energy_graph/data/raw/SMART_HOME/HomeF/2016/HomeF-meter2_2016.csv")

# print(HomeF_df_2014.columns.equals(HomeF_df_2015.columns))
# print(HomeF_df_2015.columns.equals(HomeF_df_2016.columns))

# # for house h

# # HomeH_df_2014 = pd.read_csv("./Energy_graph/data/raw/SMART_HOME/HomeH/2014/HomeH-meter2_2014.csv")
# # HomeH_df_2015 = pd.read_csv("./Energy_graph/data/raw/SMART_HOME/HomeH/2015/HomeH-meter2_2015.csv")
# HomeH_df_2016 = pd.read_csv("./Energy_graph/data/raw/SMART_HOME/HomeH/2016/HomeH-meter2_2016.csv")
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
os.listdir("../../data/")
# Out:
# ['HomeA', 'HomeB', 'HomeC', 'HomeD', 'HomeF', 'HomeG', 'HomeH']

# %%
df = pd.read_csv("./Energy_graph/data/raw/SMART_HOME/HomeA/2014/HomeA-meter2_2014.csv")

useless_columns = [outlet for outlet in df.columns if 'Outlets' in outlet]
useless_columns.append("gen [kW]")

useless_columns
df.drop(columns=useless_columns)
# Out:
#                Date & Time  use [kW]  FurnaceHRV [kW]  WashingMachine [kW]  \
# 0      2014-01-01 00:00:00       0.0         0.195338             0.005686
# 1      2014-01-01 00:30:00       0.0         0.182158             0.005679
# 2      2014-01-01 01:00:00       0.0         0.134808             0.005635
# 3      2014-01-01 01:30:00       0.0         0.182125             0.005672
# 4      2014-01-01 02:00:00       0.0         0.092988             0.005570
# ...                    ...       ...              ...                  ...
# 17515  2014-12-31 21:30:00       0.0         0.075843             0.000071
# 17516  2014-12-31 22:00:00       0.0         0.170588             0.000154
# 17517  2014-12-31 22:30:00       0.0         0.148785             0.000156
# 17518  2014-12-31 23:00:00       0.0         0.054264             0.000047
# 17519  2014-12-31 23:30:00       0.0         0.170284             0.000154
#
# ...

# %%
df = pd.read_csv("../../data/raw/SMART_HOME/HomeA/2015/HomeA-meter2_2015.csv")
df
# Out:
#                Date & Time  use [kW]  gen [kW]  FurnaceHRV [kW]  \
# 0      2015-01-01 00:00:00       0.0       0.0         0.066114
# 1      2015-01-01 00:30:00       0.0       0.0         0.115415
# 2      2015-01-01 01:00:00       0.0       0.0         0.230449
# 3      2015-01-01 01:30:00       0.0       0.0         0.603257
# 4      2015-01-01 02:00:00       0.0       0.0         0.667586
# ...                    ...       ...       ...              ...
# 17515  2015-12-31 21:30:00       0.0       0.0         0.107932
# 17516  2015-12-31 22:00:00       0.0       0.0         0.133774
# 17517  2015-12-31 22:30:00       0.0       0.0         0.113159
# 17518  2015-12-31 23:00:00       0.0       0.0         0.111407
# 17519  2015-12-31 23:30:00       0.0       0.0         0.131768
#
#        CellarOutlets [kW]  WashingMachine [kW]  FridgeRange [kW]  \
# 0                0.058830             0.000056          0.000057
# ...

# %%
df = pd.read_csv("../../data/raw/SMART_HOME/HomeA/2016/HomeA-meter2_2016.csv")
df
# Out:
#                 Date & Time  use [kW]  gen [kW]  FurnaceHRV [kW]  \
# 0       2016-01-01 00:00:00       0.0       0.0         0.084142
# 1       2016-01-01 00:30:00       0.0       0.0         0.009887
# 2       2016-01-01 01:00:00       0.0       0.0         0.044926
# 3       2016-01-01 01:30:00       0.0       0.0         0.037721
# 4       2016-01-01 02:00:00       0.0       0.0         0.010029
# ...                     ...       ...       ...              ...
# 246634  2016-12-31 23:55:00       0.0       0.0         0.086217
# 246635  2016-12-31 23:56:00       0.0       0.0         0.086217
# 246636  2016-12-31 23:57:00       0.0       0.0         0.086417
# 246637  2016-12-31 23:58:00       0.0       0.0         0.086200
# 246638  2016-12-31 23:59:00       0.0       0.0         0.086083
#
#         CellarOutlets [kW]  WashingMachine [kW]  FridgeRange [kW]  \
# 0                 0.113495             0.000123          0.001031
# ...

# %%
# Home<letter>-meter<#>_<year>.csv


# HomeA_df_2014.drop(columns=['gen [kW]', "CellarOutlets [kW]", 'BedroomOutlets [kW]','MasterOutlets [kW]'])
test_str = "HomeF-meter2_2014.csv"
def parse_name(file: str):
    str = file.split("-")
    house = str[0]
    str = str[1].split("_")
    meter = str[0]
    year = str[1].split(".")[0]
    data = {
        "house": house,
        "meter": meter,
        "year": year
    }
    return data

data= parse_name(test_str)

print("house: "+ data["house"] + "\nmeter: " + data["meter"] + "\nyear: " + data["year"])
# Out:
# house: HomeF
# meter: meter2
# year: 2014

# %%
path = "../../data/raw/SMART_HOME/"

# path = "./Energy_graph/data/raw/SMART_HOME/"
data_dict = {}

# homes = os.listdir("./Energy_graph/data/raw/SMART_HOME/")

for home in os.listdir(path):
    if "Home" in home:
        home_data = {}
        for year in os.listdir(path+home):
            for meter in os.listdir(path+home+"/"+year):
                if "meter" in meter and meter.endswith(".csv"):
                    meter_parsed = parse_name(meter)
                    meter_data = pd.read_csv(path+home+"/"+year+"/"+meter).set_index("Date & Time")
                    
                    useless_columns = [c for c in meter_data.columns if 'Outlets' in c or 'Receptables' in c]

                    useless_columns.append("gen [kW]")
                    meter_data.drop(columns=set(useless_columns).intersection(set(meter_data.columns)), inplace=True)

                    home_data.setdefault(meter_parsed["meter"], []).append(meter_data)
    data_dict[home] = home_data

# %%
data_dict["HomeA"]["meter2"]
# Out:
# [                     use [kW]  FurnaceHRV [kW]  WashingMachine [kW]  \
#  Date & Time
#  2014-01-01 00:00:00       0.0         0.195338             0.005686
#  2014-01-01 00:30:00       0.0         0.182158             0.005679
#  2014-01-01 01:00:00       0.0         0.134808             0.005635
#  2014-01-01 01:30:00       0.0         0.182125             0.005672
#  2014-01-01 02:00:00       0.0         0.092988             0.005570
#  ...                       ...              ...                  ...
#  2014-12-31 21:30:00       0.0         0.075843             0.000071
#  2014-12-31 22:00:00       0.0         0.170588             0.000154
#  2014-12-31 22:30:00       0.0         0.148785             0.000156
#  2014-12-31 23:00:00       0.0         0.054264             0.000047
#  2014-12-31 23:30:00       0.0         0.170284             0.000154
#
#                       FridgeRange [kW]  DisposalDishwasher [kW]  \
#  Date & Time
# ...

# %%
for home in data_dict:
    print(home)
    dfs = []
    for meter in data_dict[home]:
        dfs.append(pd.concat(data_dict[home][meter], axis=0))
    
    # df = pd.concat(dfs, axis=1)
    break
dfs[0].sort_index(inplace=True)
# Out:
# HomeA

# %%
dfs[0].index.unique()
# Out:
# Index(['2014-01-01 00:00:00', '2014-01-01 00:30:00', '2014-01-01 01:00:00',
#        '2014-01-01 01:30:00', '2014-01-01 02:00:00', '2014-01-01 02:30:00',
#        '2014-01-01 03:00:00', '2014-01-01 03:30:00', '2014-01-01 04:00:00',
#        '2014-01-01 04:30:00',
#        ...
#        '2016-12-31 23:50:00', '2016-12-31 23:51:00', '2016-12-31 23:52:00',
#        '2016-12-31 23:53:00', '2016-12-31 23:54:00', '2016-12-31 23:55:00',
#        '2016-12-31 23:56:00', '2016-12-31 23:57:00', '2016-12-31 23:58:00',
#        '2016-12-31 23:59:00'],
#       dtype='object', name='Date & Time', length=281615)
