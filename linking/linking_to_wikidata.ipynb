# %%
# %pip install SPARQLWrapper
# %pip install fuzzywuzzy
# %pip install geopy
from SPARQLWrapper import SPARQLWrapper, JSON
from fuzzywuzzy import fuzz
from geopy.distance import geodesic
import math
# Out:
# Requirement already satisfied: SPARQLWrapper in c:\users\foglo\anaconda3\envs\energy-graph\lib\site-packages (2.0.0)
# Requirement already satisfied: rdflib>=6.1.1 in c:\users\foglo\anaconda3\envs\energy-graph\lib\site-packages (from SPARQLWrapper) (7.0.0)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in c:\users\foglo\anaconda3\envs\energy-graph\lib\site-packages (from rdflib>=6.1.1->SPARQLWrapper) (0.6.1)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in c:\users\foglo\anaconda3\envs\energy-graph\lib\site-packages (from rdflib>=6.1.1->SPARQLWrapper) (3.0.9)
# Requirement already satisfied: six in c:\users\foglo\anaconda3\envs\energy-graph\lib\site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=6.1.1->SPARQLWrapper) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: fuzzywuzzy in c:\users\foglo\anaconda3\envs\energy-graph\lib\site-packages (0.18.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: geopy in c:\users\foglo\anaconda3\envs\energy-graph\lib\site-packages (2.4.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\foglo\anaconda3\envs\energy-graph\lib\site-packages (from geopy) (2.0)
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\foglo\anaconda3\envs\energy-graph\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
def query_wikidata_coordinates(latitude : float, longitude : float, label : str, data=None):
    if data is None:
        print("Querying Wikidata......")
        query_wikidata = f"""
        PREFIX wdt: <http://www.wikidata.org/prop/direct/>
        PREFIX wd: <http://www.wikidata.org/entity/>
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX bd: <http://www.bigdata.com/rdf#>
        PREFIX wikibase: <http://wikiba.se/ontology#>
        PREFIX geo: <http://www.opengis.net/ont/geosparql#>

        SELECT DISTINCT ?city ?cityLabel ?location
        WHERE {{
        SERVICE wikibase:around {{
            # ?city wdt:P625 ?location .
            bd:serviceParam wikibase:center "Point({longitude} {latitude})"^^geo:wktLiteral .
            bd:serviceParam wikibase:radius "50" . 
        }}
        # ?city wdt:P31/wdt:P279* wd:Q515 . 
        # ?city rdfs:label ?cityLabel .
        FILTER(LANG(?cityLabel) = "en") .
        
        }} LIMIT 1000
    
        """
        sparql_wdata = SPARQLWrapper("https://query.wikidata.org/sparql")

        sparql_wdata.setQuery(query_wikidata)

        sparql_wdata.setReturnFormat(JSON)

        results = sparql_wdata.query().convert()
    else:
        results = data

        
    matched_cities = []
    
    for r in results["results"]["bindings"]:
        ratio_partial = fuzz.partial_ratio(r["cityLabel"]["value"], label)
        ratio = fuzz.ratio(r["cityLabel"]["value"], label)

        ratio = (ratio + ratio_partial) / 2
        if ratio > 80:
            matched_cities.append((ratio, r))

    if len(matched_cities) == 0:
        min_distance = math.inf
        for r in results["results"]["bindings"]:
            coords = r["location"]["value"].split("(")[1].split(")")[0].split(" ")
            coords = (float(coords[1]), float(coords[0]))
            distance = geodesic((latitude, longitude), coords).kilometers
            if distance < min_distance:
                min_distance = distance
                closest_city = r
        return closest_city
    
    matched_cities.sort(key=lambda x: x[0], reverse=True)
    return matched_cities[0][1]

def get_wikidata_results(latitude : float, longitude : float):
    query_wikidata = f"""
    PREFIX wdt: <http://www.wikidata.org/prop/direct/>
    PREFIX wd: <http://www.wikidata.org/entity/>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX bd: <http://www.bigdata.com/rdf#>
    PREFIX wikibase: <http://wikiba.se/ontology#>
    PREFIX geo: <http://www.opengis.net/ont/geosparql#>

    SELECT DISTINCT ?city ?cityLabel ?location
    WHERE {{
    SERVICE wikibase:around {{
        # ?city wdt:P625 ?location .
        bd:serviceParam wikibase:center "Point({longitude} {latitude})"^^geo:wktLiteral .
        bd:serviceParam wikibase:radius "50" . 
    }}
    # ?city wdt:P31/wdt:P279* wd:Q515 . 
    # ?city rdfs:label ?cityLabel .
    FILTER(LANG(?cityLabel) = "en") .

    }} LIMIT 1000

    """
     
    sparql_wdata = SPARQLWrapper("https://query.wikidata.org/sparql")

    sparql_wdata.setQuery(query_wikidata)

    sparql_wdata.setReturnFormat(JSON)

    results = sparql_wdata.query().convert()
    return results

def get_dbpedia_results(latitude : float, longitude : float):
    query = f"""
    PREFIX dbo: <http://dbpedia.org/ontology/>
    PREFIX dbr: <http://dbpedia.org/resource/>
    PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

    SELECT DISTINCT ?city ?cityLabel 
    WHERE {{
      # ?city a dbo:City .
      # ?city rdfs:label ?cityLabel .
      # ?city geo:lat ?lat .
      # ?city geo:long ?long .
      FILTER (LANG(?cityLabel) = "en")
      FILTER (
        bif:st_intersects (
          bif:st_point (?long, ?lat),
          bif:st_point ({longitude}, {latitude}),
          50
        )
      )
    }}
    LIMIT 1000


    """

    sparql_dbpedia = SPARQLWrapper("http://dbpedia.org/sparql")

    sparql_dbpedia.setQuery(query)

    sparql_dbpedia.setReturnFormat(JSON)

    results = sparql_dbpedia.query().convert()

    return results

def query_dbpedia_coordinates(latitude : float, longitude : float, label : str, data=None):
    if data is None:
        print("Querying DBpedia......")
        query = f"""
        PREFIX dbo: <http://dbpedia.org/ontology/>
        PREFIX dbr: <http://dbpedia.org/resource/>
        PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

        SELECT DISTINCT ?city ?cityLabel ?lat ?long
        WHERE {{
          # ?city a dbo:City .
          # ?city rdfs:label ?cityLabel .
          # ?city geo:lat ?lat .
          # ?city geo:long ?long .
          FILTER (LANG(?cityLabel) = "en")
          FILTER (
            bif:st_intersects (
              bif:st_point (?long, ?lat),
              bif:st_point ({longitude}, {latitude}),
              50
            )
          )
        }}
        LIMIT 1000


        """

        sparql_dbpedia = SPARQLWrapper("http://dbpedia.org/sparql")

        sparql_dbpedia.setQuery(query)

        sparql_dbpedia.setReturnFormat(JSON)

        results = sparql_dbpedia.query().convert()
    else:
        results = data

    matched_cities = []
    
    for r in results["results"]["bindings"]:
        ratio_partial = fuzz.partial_ratio(r["cityLabel"]["value"], label)
        ratio = fuzz.ratio(r["cityLabel"]["value"], label)

        ratio = (ratio + ratio_partial) / 2

        if ratio > 80:
            matched_cities.append((ratio, r))

    if len(matched_cities) == 0:
        min_distance = math.inf
        for r in results["results"]["bindings"]:
            coords = (float(r["lat"]["value"]), float(r["long"]["value"]))
            distance = geodesic((latitude, longitude), coords).kilometers
            if distance < min_distance:
                min_distance = distance
                closest_city = r

        return closest_city
    
    matched_cities.sort(key=lambda x: x[0], reverse=True)
    return matched_cities[0][1]


def query_graphDB():
    query_my_data = """
    PREFIX schema: <https://schema.org/>
    PREFIX wdtn: <http://www.wikidata.org/prop/direct-normalized/>
    PREFIX data: <http://mydata.example.org/>
    PREFIX owl: <http://www.w3.org/2002/07/owl#>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX wdt: <http://www.wikidata.org/prop/direct/>
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX voc: <http://vocabulary.example.org/>
    PREFIX wd: <http://www.wikidata.org/entity/>
    SELECT DISTINCT ?cityName ?longitude ?latitude ?City
    WHERE {
    # ?s rdf:type schema:Place .
    # ?s schema:containedInPlace ?City .
    # ?City rdf:type schema:City .
    # ?City schema:name ?cityName .
    # ?s schema:longitude ?longitude .
    # ?s schema:latitude ?latitude . 
    }
    """
    # endpoint = "http://localhost:7200/repositories/test"
    endpoint = "http://193.2.205.14:7200/repositories/EnergyGraph"

    sparlq_graphdb = SPARQLWrapper(endpoint)
    sparlq_graphdb.setQuery(query_my_data)
    sparlq_graphdb.setReturnFormat(JSON)
    results_Graphdb = sparlq_graphdb.query().convert()

    return results_Graphdb

# %%
query_my_data = """
PREFIX schema: <https://schema.org/>
PREFIX wdtn: <http://www.wikidata.org/prop/direct-normalized/>
PREFIX data: <http://mydata.example.org/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX voc: <http://vocabulary.example.org/>
PREFIX wd: <http://www.wikidata.org/entity/>
SELECT DISTINCT ?cityName ?longitude ?latitude ?City
WHERE {
# ?s rdf:type schema:Place .
# ?s schema:containedInPlace ?City .
# ?City rdf:type schema:City .
# ?City schema:name ?cityName .
# ?s schema:longitude ?longitude .
# ?s schema:latitude ?latitude . 
}
"""
# "http://localhost:7200/repositories/yourRepository"

sparlq_graphdb = SPARQLWrapper("http://localhost:7200/repositories/test")
sparlq_graphdb.setQuery(query_my_data)
sparlq_graphdb.setReturnFormat(JSON)
results_Graphdb = sparlq_graphdb.query().convert()

# %%
results = query_graphDB()
data = {}
matches= []
for c in results["results"]["bindings"]:
    label = c["cityName"]["value"]
    longitude = float(c["longitude"]["value"])
    latitude = float(c["latitude"]["value"])
    data[label] = get_wikidata_results(latitude, longitude)

# %%
results = query_graphDB()
results
# Out:
# {'head': {'vars': ['cityName', 'longitude', 'latitude', 'City']},
#  'results': {'bindings': [{'cityName': {'type': 'literal',
#      'value': 'City of Edinburgh'},
#     'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '-3.1883E0'},
#     'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '5.59533E1'},
#     'City': {'type': 'uri',
#      'value': 'http://mydata.example.org/public-locations-City/City%20of%20Edinburgh'}},
#    {'cityName': {'type': 'literal', 'value': 'City of Edinburgh'},
#     'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '-3.1883E0'},
#     'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '5.59533E1'},
#     'City': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q23436'}},
#    {'cityName': {'type': 'literal', 'value': 'City of Edinburgh'},
#     'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '-3.1883E0'},
#     'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '5.59533E1'},
#     'City': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Edinburgh'}},
#    {'cityName': {'type': 'literal', 'value': 'London'},
#     'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '-7.6544E-2'},
#     'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '5.1464462E1'},
#     'City': {'type': 'uri',
#      'value': 'http://mydata.example.org/public-locations-City/London'}},
#    {'cityName': {'type': 'literal', 'value': 'London'},
#     'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '-7.6544E-2'},
#     'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '5.1464462E1'},
#     'City': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q84'}},
#    {'cityName': {'type': 'literal', 'value': 'London'},
#     'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '-7.6544E-2'},
#     'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '5.1464462E1'},
#     'City': {'type': 'uri', 'value': 'http://dbpedia.org/resource/London'}},
#    {'cityName': {'type': 'literal', 'value': 'Boston'},
#     'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '-7.1064709E1'},
#     'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '4.2360338E1'},
#     'City': {'type': 'uri',
#      'value': 'http://mydata.example.org/public-locations-City/Boston'}},
#    {'cityName': {'type': 'literal', 'value': 'Boston'},
#     'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '-7.1064709E1'},
#     'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '4.2360338E1'},
#     'City': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q100'}},
#    {'cityName': {'type': 'literal', 'value': 'Boston'},
#     'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '-7.1064709E1'},
#     'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '4.2360338E1'},
#     'City': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Boston'}},
#    {'cityName': {'type': 'literal', 'value': 'Montreal'},
#     'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '-7.3561668E1'},
#     'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '4.5508888E1'},
#     'City': {'type': 'uri',
#      'value': 'http://mydata.example.org/public-locations-City/Montreal'}},
#    {'cityName': {'type': 'literal', 'value': 'Montreal'},
#     'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '-7.3561668E1'},
#     'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '4.5508888E1'},
#     'City': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q340'}},
#    {'cityName': {'type': 'literal', 'value': 'Montreal'},
#     'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '-7.3561668E1'},
#     'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '4.5508888E1'},
#     'City': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Montreal'}},
#    {'cityName': {'type': 'literal', 'value': 'Abbotsford'},
#     'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '-1.2235E2'},
#     'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '4.9083333E1'},
#     'City': {'type': 'uri',
#      'value': 'http://mydata.example.org/public-locations-City/Abbotsford'}},
#    {'cityName': {'type': 'literal', 'value': 'Abbotsford'},
#     'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '-1.2235E2'},
#     'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '4.9083333E1'},
#     'City': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q271730'}},
#    {'cityName': {'type': 'literal', 'value': 'Abbotsford'},
#     'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '-1.2235E2'},
#     'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '4.9083333E1'},
#     'City': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Abbotsford,_British_Columbia'}},
#    {'cityName': {'type': 'literal', 'value': 'Charnwood'},
#     'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '-1.2097E0'},
#     'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '5.27709E1'},
#     'City': {'type': 'uri',
#      'value': 'http://mydata.example.org/public-locations-City/Charnwood'}},
#    {'cityName': {'type': 'literal', 'value': 'Charnwood'},
#     'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '-1.2097E0'},
#     'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '5.27709E1'},
#     'City': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q83065'}},
#    {'cityName': {'type': 'literal', 'value': 'Charnwood'},
#     'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '-1.2097E0'},
#     'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'type': 'literal',
#      'value': '5.27709E1'},
#     'City': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Loughborough'}}]}}

# %%
type(data)
# Out:
# dict

# %%
results = query_graphDB()
matches= []
for c in results["results"]["bindings"]:
    label = c["cityName"]["value"]
    # if label != "Montreal":
    #     continue
    longitude = float(c["longitude"]["value"])
    latitude = float(c["latitude"]["value"])
    print(label, longitude, latitude)
    result_dbpedia = (c,query_dbpedia_coordinates(latitude, longitude, label))
    result_wikidata = (c,query_wikidata_coordinates(latitude, longitude, label))
    matches.append(result_dbpedia)
    matches.append(result_wikidata)
matches
# Out:
# Abbotsford -122.35 49.083333
# Querying DBpedia......
# Querying Wikidata......
# Charnwood -1.2097 52.7709
# Querying DBpedia......
# Querying Wikidata......
# Montreal -73.561668 45.508888
# Querying DBpedia......
# Querying Wikidata......
# London -0.076544 51.464462
# Querying DBpedia......
# Querying Wikidata......
# Boston -71.064709 42.360338
# Querying DBpedia......
# Querying Wikidata......
# City of Edinburgh -3.1883 55.9533
# Querying DBpedia......
# Querying Wikidata......
# [({'cityName': {'type': 'literal', 'value': 'Abbotsford'},
#    'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#     'type': 'literal',
#     'value': '-1.2235E2'},
#    'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#     'type': 'literal',
#     'value': '4.9083333E1'},
#    'City': {'type': 'uri',
#     'value': 'http://mydata.example.org/public-locations-City/Abbotsford'}},
#   {'city': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Abbotsford,_British_Columbia'},
#    'cityLabel': {'type': 'literal',
#     'xml:lang': 'en',
#     'value': 'Abbotsford, British Columbia'},
#    'lat': {'type': 'typed-literal',
#     'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#     'value': '49.05'},
#    'long': {'type': 'typed-literal',
#     'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#     'value': '-122.317'}}),
#  ({'cityName': {'type': 'literal', 'value': 'Abbotsford'},
#    'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#     'type': 'literal',
#     'value': '-1.2235E2'},
#    'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#     'type': 'literal',
#     'value': '4.9083333E1'},
#    'City': {'type': 'uri',
#     'value': 'http://mydata.example.org/public-locations-City/Abbotsford'}},
#   {'city': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q271730'},
#    'location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#     'type': 'literal',
#     'value': 'Point(-122.328 49.054611111)'},
#    'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Abbotsford'}}),
#  ({'cityName': {'type': 'literal', 'value': 'Charnwood'},
#    'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#     'type': 'literal',
#     'value': '-1.2097E0'},
#    'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#     'type': 'literal',
#     'value': '5.27709E1'},
#    'City': {'type': 'uri',
#     'value': 'http://mydata.example.org/public-locations-City/Charnwood'}},
#   {'city': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Loughborough'},
#    'cityLabel': {'type': 'literal', 'xml:lang': 'en', 'value': 'Loughborough'},
#    'lat': {'type': 'typed-literal',
#     'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#     'value': '52.77'},
#    'long': {'type': 'typed-literal',
#     'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#     'value': '-1.2'}}),
#  ({'cityName': {'type': 'literal', 'value': 'Charnwood'},
#    'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#     'type': 'literal',
#     'value': '-1.2097E0'},
#    'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#     'type': 'literal',
#     'value': '5.27709E1'},
#    'City': {'type': 'uri',
#     'value': 'http://mydata.example.org/public-locations-City/Charnwood'}},
#   {'city': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q83065'},
#    'location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#     'type': 'literal',
#     'value': 'Point(-1.133333333 52.633333333)'},
#    'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Leicester'}}),
#  ({'cityName': {'type': 'literal', 'value': 'Montreal'},
#    'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#     'type': 'literal',
#     'value': '-7.3561668E1'},
#    'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#     'type': 'literal',
#     'value': '4.5508888E1'},
#    'City': {'type': 'uri',
#     'value': 'http://mydata.example.org/public-locations-City/Montreal'}},
#   {'city': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Montreal'},
#    'cityLabel': {'type': 'literal', 'xml:lang': 'en', 'value': 'Montreal'},
#    'lat': {'type': 'typed-literal',
#     'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#     'value': '45.5089'},
#    'long': {'type': 'typed-literal',
#     'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#     'value': '-73.5542'}}),
#  ({'cityName': {'type': 'literal', 'value': 'Montreal'},
#    'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#     'type': 'literal',
#     'value': '-7.3561668E1'},
#    'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#     'type': 'literal',
#     'value': '4.5508888E1'},
#    'City': {'type': 'uri',
#     'value': 'http://mydata.example.org/public-locations-City/Montreal'}},
#   {'city': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q340'},
#    'location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#     'type': 'literal',
#     'value': 'Point(-73.561666666 45.508888888)'},
#    'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Montreal'}}),
#  ({'cityName': {'type': 'literal', 'value': 'London'},
#    'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#     'type': 'literal',
#     'value': '-7.6544E-2'},
#    'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#     'type': 'literal',
#     'value': '5.1464462E1'},
#    'City': {'type': 'uri',
#     'value': 'http://mydata.example.org/public-locations-City/London'}},
#   {'city': {'type': 'uri', 'value': 'http://dbpedia.org/resource/London'},
#    'cityLabel': {'type': 'literal', 'xml:lang': 'en', 'value': 'London'},
#    'lat': {'type': 'typed-literal',
#     'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#     'value': '51.5072'},
#    'long': {'type': 'typed-literal',
#     'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#     'value': '-0.1275'}}),
#  ({'cityName': {'type': 'literal', 'value': 'London'},
#    'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#     'type': 'literal',
#     'value': '-7.6544E-2'},
#    'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#     'type': 'literal',
#     'value': '5.1464462E1'},
#    'City': {'type': 'uri',
#     'value': 'http://mydata.example.org/public-locations-City/London'}},
#   {'city': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q84'},
#    'location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#     'type': 'literal',
#     'value': 'Point(-0.1275 51.507222222)'},
#    'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}}),
#  ({'cityName': {'type': 'literal', 'value': 'Boston'},
#    'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#     'type': 'literal',
#     'value': '-7.1064709E1'},
#    'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#     'type': 'literal',
#     'value': '4.2360338E1'},
#    'City': {'type': 'uri',
#     'value': 'http://mydata.example.org/public-locations-City/Boston'}},
#   {'city': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Boston'},
#    'cityLabel': {'type': 'literal', 'xml:lang': 'en', 'value': 'Boston'},
#    'lat': {'type': 'typed-literal',
#     'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#     'value': '42.3603'},
#    'long': {'type': 'typed-literal',
#     'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#     'value': '-71.0578'}}),
#  ({'cityName': {'type': 'literal', 'value': 'Boston'},
#    'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#     'type': 'literal',
#     'value': '-7.1064709E1'},
#    'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#     'type': 'literal',
#     'value': '4.2360338E1'},
#    'City': {'type': 'uri',
#     'value': 'http://mydata.example.org/public-locations-City/Boston'}},
#   {'city': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q100'},
#    'location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#     'type': 'literal',
#     'value': 'Point(-71.057777777 42.360277777)'},
#    'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Boston'}}),
#  ({'cityName': {'type': 'literal', 'value': 'City of Edinburgh'},
#    'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#     'type': 'literal',
#     'value': '-3.1883E0'},
#    'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#     'type': 'literal',
#     'value': '5.59533E1'},
#    'City': {'type': 'uri',
#     'value': 'http://mydata.example.org/public-locations-City/City%20of%20Edinburgh'}},
#   {'city': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Edinburgh'},
#    'cityLabel': {'type': 'literal', 'xml:lang': 'en', 'value': 'Edinburgh'},
#    'lat': {'type': 'typed-literal',
#     'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#     'value': '55.9533'},
#    'long': {'type': 'typed-literal',
#     'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#     'value': '-3.18917'}}),
#  ({'cityName': {'type': 'literal', 'value': 'City of Edinburgh'},
#    'longitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#     'type': 'literal',
#     'value': '-3.1883E0'},
#    'latitude': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#     'type': 'literal',
#     'value': '5.59533E1'},
#    'City': {'type': 'uri',
#     'value': 'http://mydata.example.org/public-locations-City/City%20of%20Edinburgh'}},
#   {'city': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q23436'},
#    'location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#     'type': 'literal',
#     'value': 'Point(-3.189166666 55.953333333)'},
#    'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Edinburgh'}})]

# %%
# matches[0][0]["City"]["value"], matches[0][1]["city"]["value"]

# s = "<"+matches[0][0]["City"]["value"] +"> " + "<http://www.w3.org/2002/07/owl#sameAs> " + "<"+matches[0][1]["city"]["value"] +"> ."
triples = []
for m in matches:
    s = "<"+m[0]["City"]["value"] +"> " + "<http://www.w3.org/2002/07/owl#sameAs> " + "<"+m[1]["city"]["value"] +"> .\n"
    triples.append(s)

# %%
with open("matches.nt", "w") as f:
    f.writelines(triples)

# %% [markdown]
# # DBPedia

# %%
latitude = 45.5128
longitude = -73.56
def query_dbpedia_coordinates(latitude, longitude):
    query = f"""
    PREFIX dbo: <http://dbpedia.org/ontology/>
    PREFIX dbr: <http://dbpedia.org/resource/>
    PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

    SELECT DISTINCT ?city ?cityLabel  ?lat ?long
    WHERE {{
      # ?city a dbo:City .
      # ?city rdfs:label ?cityLabel .
      # ?city geo:lat ?lat .
      # ?city geo:long ?long .
      FILTER (LANG(?cityLabel) = "en")
      FILTER (
        bif:st_intersects (
          bif:st_point (?long, ?lat),
          bif:st_point ({longitude}, {latitude}),
          50
        )
      )
    }}
    LIMIT 1000


    """

    sparql_dbpedia = SPARQLWrapper("http://dbpedia.org/sparql")

    sparql_dbpedia.setQuery(query)

    sparql_dbpedia.setReturnFormat(JSON)

    results = sparql_dbpedia.query().convert()
    return results


results = query_dbpedia_coordinates(latitude, longitude)
results
# Out:
# {'head': {'link': [], 'vars': ['city', 'cityLabel', 'lat', 'long']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Carignan,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Carignan, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.45'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.3'}},
#    {'city': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Rosemère'},
#     'cityLabel': {'type': 'literal', 'xml:lang': 'en', 'value': 'Rosemère'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.6369'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.8'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Beaconsfield,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Beaconsfield, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.4333'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.8667'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Beauharnois,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Beauharnois, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.3247'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.8531'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Beloeil,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Beloeil, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.5667'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.2'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Bois-des-Filion'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Bois-des-Filion'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.6667'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.75'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Boucherville'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Boucherville'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.6'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.45'}},
#    {'city': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Delson'},
#     'cityLabel': {'type': 'literal', 'xml:lang': 'en', 'value': 'Delson'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.4017'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.5364'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Deux-Montagnes'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Deux-Montagnes'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.5333'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.8833'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Hudson,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Hudson, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.45'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-74.15'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Repentigny,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Repentigny, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.7333'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.4667'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Richelieu,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Richelieu, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.45'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.25'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Varennes,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Varennes, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.6833'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.4333'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Vaudreuil-Dorion'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Vaudreuil-Dorion'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.4'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-74.0333'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Contrecœur,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Contrecœur, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.85'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.2333'}},
#    {'city': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Mascouche'},
#     'cityLabel': {'type': 'literal', 'xml:lang': 'en', 'value': 'Mascouche'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.75'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.6'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Saint-Amable'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Saint-Amable'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.65'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.3'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Saint-Bruno-de-Montarville'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Saint-Bruno-de-Montarville'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.5333'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.35'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Saint-Césaire,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Saint-Césaire, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.4167'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.0'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Saint-Eustache,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Saint-Eustache, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.57'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.9'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Saint-Hyacinthe'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Saint-Hyacinthe'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.6167'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-72.95'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Saint-Jean-sur-Richelieu'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Saint-Jean-sur-Richelieu'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.3167'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.2667'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Saint-Jérôme'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Saint-Jérôme'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.7833'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-74.0'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Saint-Lambert,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Saint-Lambert, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.5'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.5167'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Saint-Lin–Laurentides'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Saint-Lin–Laurentides'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.85'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.7667'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Saint-Rémi,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Saint-Rémi, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.2667'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.6167'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Sainte-Anne-de-Bellevue'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Sainte-Anne-de-Bellevue'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.4039'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.9525'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Sainte-Anne-des-Plaines'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Sainte-Anne-des-Plaines'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.7667'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.8167'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Geography_of_Montreal'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Geography of Montreal'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.5'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.5833'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Mirabel,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Mirabel, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.6636'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-74.0019'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Mont-Saint-Hilaire'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Mont-Saint-Hilaire'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.5622'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.1917'}},
#    {'city': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Montreal'},
#     'cityLabel': {'type': 'literal', 'xml:lang': 'en', 'value': 'Montreal'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.5089'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.5542'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Montreal_West,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Montreal West, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.4536'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.6472'}},
#    {'city': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Longueuil'},
#     'cityLabel': {'type': 'literal', 'xml:lang': 'en', 'value': 'Longueuil'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.5333'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.5167'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Lorraine,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Lorraine, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.6833'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.7833'}},
#    {'city': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Brossard'},
#     'cityLabel': {'type': 'literal', 'xml:lang': 'en', 'value': 'Brossard'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.4667'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.45'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Westmount,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Westmount, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.4833'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.6'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Côte_Saint-Luc'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Côte Saint-Luc'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.4667'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.6667'}},
#    {'city': {'type': 'uri',
#      'value': "http://dbpedia.org/resource/Notre-Dame-de-l'Île-Perrot"},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': "Notre-Dame-de-l'Île-Perrot"},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.3667'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.9333'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Otterburn_Park'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Otterburn Park'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.5333'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.2167'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Greenfield_Park,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Greenfield Park, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.492'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.487'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Hampstead,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Hampstead, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.4833'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.6333'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Terrebonne,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Terrebonne, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.7'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.6333'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Chambly,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Chambly, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.45'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.2833'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Charlemagne,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Charlemagne, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.7167'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.4833'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Chomedey,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Chomedey, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.55'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.7333'}},
#    {'city': {'type': 'uri',
#      'value': "http://dbpedia.org/resource/L'Assomption,_Quebec"},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': "L'Assomption, Quebec"},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.8333'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.4167'}},
#    {'city': {'type': 'uri',
#      'value': "http://dbpedia.org/resource/L'Épiphanie,_Quebec_(town)"},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': "L'Épiphanie, Quebec (town)"},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.85'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.4833'}},
#    {'city': {'type': 'uri',
#      'value': "http://dbpedia.org/resource/L'Île-Bizard,_Quebec"},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': "L'Île-Bizard, Quebec"},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.4874'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.8799'}},
#    {'city': {'type': 'uri',
#      'value': "http://dbpedia.org/resource/L'Île-Cadieux"},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': "L'Île-Cadieux"},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.4333'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-74.0167'}},
#    {'city': {'type': 'uri',
#      'value': "http://dbpedia.org/resource/L'Île-Dorval"},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': "L'Île-Dorval"},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.4322'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.7414'}},
#    {'city': {'type': 'uri',
#      'value': "http://dbpedia.org/resource/L'Île-Perrot,_Quebec"},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': "L'Île-Perrot, Quebec"},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.3833'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.95'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Laval,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Laval, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.5833'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.75'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Laval-Ouest'},
#     'cityLabel': {'type': 'literal', 'xml:lang': 'en', 'value': 'Laval-Ouest'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.55'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.8667'}},
#    {'city': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Lavaltrie'},
#     'cityLabel': {'type': 'literal', 'xml:lang': 'en', 'value': 'Lavaltrie'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.8833'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.2833'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Dollard-des-Ormeaux'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Dollard-des-Ormeaux'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.4833'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.8167'}},
#    {'city': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Dorval'},
#     'cityLabel': {'type': 'literal', 'xml:lang': 'en', 'value': 'Dorval'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.45'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.75'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Marieville,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Marieville, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.4333'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.1667'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Pierrefonds,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Pierrefonds, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.4667'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.8833'}},
#    {'city': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Pincourt'},
#     'cityLabel': {'type': 'literal', 'xml:lang': 'en', 'value': 'Pincourt'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.3833'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.9833'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Place_Émilie-Gamelin'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Place Émilie-Gamelin'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.5154'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.56'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Pointe-Claire'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Pointe-Claire'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.45'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.8167'}},
#    {'city': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Iberville,_Quebec'},
#     'cityLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Iberville, Quebec'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '45.3167'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'value': '-73.2333'}}]}}

# %%
results = query_graphDB()
matches= []
for c in results["results"]["bindings"]:
    label = c["cityName"]["value"]
    longitude = float(c["longitude"]["value"])
    latitude = float(c["latitude"]["value"])
    print(label, longitude, latitude)
    result_wikidata = (c,query_dbpedia_coordinates(latitude, longitude, label, data=data[label]))
    matches.append(result_wikidata)
results

# %%
results["results"]["bindings"][0]["cityLabel"]["value"]
# Out:
# 'Carignan, Quebec'

# %% [markdown]
# # Linked geodata

# %%
# montreal cooridinates
latitude = 45.5128
longitude = -73.56

query = f"""
PREFIX lgdo: <http://linkedgeodata.org/ontology/>
PREFIX geom: <http://geovocab.org/geometry#>
PREFIX ogc: <http://www.opengis.net/ont/geosparql#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>

SELECT DISTINCT ?city ?cityLabel ?lat ?long
WHERE {{
  # ?city a lgdo:City ;
        rdfs:label ?cityLabel ;
        geo:lat ?lat ;
        geo:long ?long .
  FILTER (LANG(?cityLabel) = "en")
  FILTER (
    bif:st_intersects (
      bif:st_point(?long, ?lat),
      bif:st_point({longitude}, {latitude}),
      50
    )
  )
}}
LIMIT 1000



"""

sparql_linkedgeodata = SPARQLWrapper("http://linkedgeodata.org/sparql")
sparql_linkedgeodata.setQuery(query)
sparql_linkedgeodata.setReturnFormat(JSON)
results = sparql_linkedgeodata.query().convert()

results
# Out:
# {'head': {'link': [], 'vars': ['city', 'cityLabel', 'lat', 'long']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'city': {'type': 'uri',
#      'value': 'http://linkedgeodata.org/triplify/node299790200'},
#     'cityLabel': {'type': 'literal', 'xml:lang': 'en', 'value': 'Montreal'},
#     'lat': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'value': '45.5088'},
#     'long': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#      'value': '-73.554'}}]}}
