# %%
# %pip install spacy spacy-transformers
# %pip install fuzzywuzzy
# %pip install python-Levenshtein
# %pip install transformers
# %pip install gensim
# %pip install nltk
# %pip install sklearn scipy
# Out:
# Requirement already satisfied: spacy in /opt/conda/lib/python3.10/site-packages (3.6.1)
# Requirement already satisfied: spacy-transformers in /opt/conda/lib/python3.10/site-packages (1.2.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/conda/lib/python3.10/site-packages (from spacy) (2.3.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (4.66.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.10/site-packages (from spacy) (2.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /opt/conda/lib/python3.10/site-packages (from spacy) (8.1.12)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from spacy) (65.5.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/conda/lib/python3.10/site-packages (from spacy) (6.4.0)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (1.23.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy) (2.0.7)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/conda/lib/python3.10/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (21.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/conda/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/conda/lib/python3.10/site-packages (from spacy) (2.4.7)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (1.0.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: pathy>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (0.10.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (2.28.1)
# Requirement already satisfied: transformers<4.31.0,>=3.4.0 in /opt/conda/lib/python3.10/site-packages (from spacy-transformers) (4.30.2)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in /opt/conda/lib/python3.10/site-packages (from spacy-transformers) (0.9.0)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from spacy-transformers) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: pydantic-core==2.6.3 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.6.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/conda/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers) (11.7.99)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers) (1.11.1)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers) (2.14.3)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers) (11.4.0.1)
# Requirement already satisfied: triton==2.0.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers) (2.0.0)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers) (11.7.101)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers) (10.9.0.58)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers) (11.10.3.66)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers) (3.12.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers) (2.8.8)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers) (10.2.10.91)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers) (11.7.91)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers) (11.7.4.91)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers) (11.7.99)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.8.0->spacy-transformers) (0.38.4)
# Requirement already satisfied: lit in /opt/conda/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.8.0->spacy-transformers) (16.0.6)
# Requirement already satisfied: cmake in /opt/conda/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.8.0->spacy-transformers) (3.27.4.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers<4.31.0,>=3.4.0->spacy-transformers) (2023.8.8)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from transformers<4.31.0,>=3.4.0->spacy-transformers) (0.3.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /opt/conda/lib/python3.10/site-packages (from transformers<4.31.0,>=3.4.0->spacy-transformers) (0.16.4)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /opt/conda/lib/python3.10/site-packages (from transformers<4.31.0,>=3.4.0->spacy-transformers) (0.13.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers<4.31.0,>=3.4.0->spacy-transformers) (6.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->spacy) (2.1.1)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers<4.31.0,>=3.4.0->spacy-transformers) (2022.11.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8.0->spacy-transformers) (1.2.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: fuzzywuzzy in /opt/conda/lib/python3.10/site-packages (0.18.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-Levenshtein in /opt/conda/lib/python3.10/site-packages (0.21.1)
# Requirement already satisfied: Levenshtein==0.21.1 in /opt/conda/lib/python3.10/site-packages (from python-Levenshtein) (0.21.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=2.3.0 in /opt/conda/lib/python3.10/site-packages (from Levenshtein==0.21.1->python-Levenshtein) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (4.30.2)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.23.5)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers) (3.12.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.28.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.13.3)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2023.8.8)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.3.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.16.4)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2022.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gensim in /opt/conda/lib/python3.10/site-packages (4.3.2)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.10/site-packages (from gensim) (6.4.0)
# Requirement already satisfied: scipy>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from gensim) (1.9.3)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/lib/python3.10/site-packages (from gensim) (1.23.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk) (4.66.1)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk) (8.1.3)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk) (2023.8.8)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: sklearn in /opt/conda/lib/python3.10/site-packages (0.0.post9)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (1.9.3)
# Requirement already satisfied: numpy<1.26.0,>=1.18.5 in /opt/conda/lib/python3.10/site-packages (from scipy) (1.23.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy download en_core_web_lg
# !python -m spacy download en_core_web_trf
# Out:
# 2023-09-07 07:47:32.972005: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Collecting en-core-web-lg==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.6.0/en_core_web_lg-3.6.0-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 4.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /opt/conda/lib/python3.10/site-packages (from en-core-web-lg==3.6.0) (3.6.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.1.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (21.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.0.12)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (4.66.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.0.4)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (8.1.12)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.0.8)
# Requirement already satisfied: pathy>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (0.10.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.3.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (65.5.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.0.9)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.1.2)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (0.9.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.4.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.28.1)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.23.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.0.7)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.0.9)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (0.5.0)
# Requirement already satisfied: pydantic-core==2.6.3 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.6.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (4.7.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2023.7.22)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.26.13)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/conda/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (0.1.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# 2023-09-07 07:47:55.476843: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Collecting en-core-web-trf==3.6.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.6.1/en_core_web_trf-3.6.1-py3-none-any.whl (460.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 460.3/460.3 MB 5.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /opt/conda/lib/python3.10/site-packages (from en-core-web-trf==3.6.1) (3.6.1)
# Requirement already satisfied: spacy-transformers<1.3.0,>=1.2.2 in /opt/conda/lib/python3.10/site-packages (from en-core-web-trf==3.6.1) (1.2.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (3.0.8)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (1.1.2)
# Requirement already satisfied: pathy>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (0.10.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (3.1.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (2.0.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (2.3.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (65.5.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (4.66.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (2.0.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (3.0.12)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (6.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (2.28.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (1.0.9)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (1.0.4)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (8.1.12)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (21.3)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (0.9.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (2.4.7)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (1.23.5)
# Requirement already satisfied: transformers<4.31.0,>=3.4.0 in /opt/conda/lib/python3.10/site-packages (from spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (4.30.2)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (2.0.1)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in /opt/conda/lib/python3.10/site-packages (from spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (0.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (3.0.9)
# Requirement already satisfied: pydantic-core==2.6.3 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (2.6.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (0.5.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (4.7.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (2023.7.22)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (1.26.13)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (0.1.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/conda/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (0.7.10)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (11.4.0.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (11.7.99)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (2.8.8)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (10.2.10.91)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (11.7.101)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (11.7.91)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (10.9.0.58)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (11.10.3.66)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (11.7.4.91)
# Requirement already satisfied: triton==2.0.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (2.0.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (3.12.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (1.11.1)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (11.7.99)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (0.38.4)
# Requirement already satisfied: cmake in /opt/conda/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (3.27.4.1)
# Requirement already satisfied: lit in /opt/conda/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (16.0.6)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /opt/conda/lib/python3.10/site-packages (from transformers<4.31.0,>=3.4.0->spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from transformers<4.31.0,>=3.4.0->spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (0.3.3)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers<4.31.0,>=3.4.0->spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (2023.8.8)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers<4.31.0,>=3.4.0->spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /opt/conda/lib/python3.10/site-packages (from transformers<4.31.0,>=3.4.0->spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (0.16.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-trf==3.6.1) (2.1.1)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers<4.31.0,>=3.4.0->spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (2022.11.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->en-core-web-trf==3.6.1) (1.2.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')

# %%
import spacy
import pandas as pd
from tqdm import tqdm
import numpy as np
import os
from fuzzywuzzy import fuzz
from collections import defaultdict
import re
# Out:
# 2023-09-07 08:04:02.501654: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Functions

# %%
def preprocess_string(string : str) -> str:
    string = string.lower().strip()
    string = re.sub(' +', ' ', string)
    string = string.replace("_", " ")
    string = string.replace("-", " ")
    string = string.replace("&", " ")
    string = string.split("(")[0]
    string = string.split("#")[0]

    string = string.strip()

    # handle known synoynms
    synonyms = {
        "refrigerator": "fridge",
        "vaccumcleaner": "vacuum cleaner",
        "breadmaker": "bread maker",
      
        
    }
    if string in synonyms:
        string = synonyms[string]

    if 'hi fi' in string:
        string = "audio system"

    if "router" in string:
        string = "router"

    if "treadmill" in string:
        string = "running machine"
        

    if "laptop" in string:
        string = "laptop"
    
    if "server" in string:
        string = "server"

    if "monitor" in string and not "baby" in string:
        string = "monitor"
    # special cases
    if "computer" in string and "charger" not in string:
        string = "pc"

    if "tv" in string:
        string = "television"

    if "television" in string:
        string = "television"

    if "macbook" in string:
        string = "laptop"
        
    if "car charger" == string:
        string = "ev"
    
    if "toast" in string:
        string = "toaster"
    
    if "modem" in string:
        string = "router"

    # we treat all audio devices as speakers so subwoofer is also a speaker
    if "subwoofer" in string:
        string = "speaker"

    if "speaker" in string:
        string = "speaker"

    if "iron" in string and "soldering" not in string:
        string = "iron"

    
    if "coffeemachine" in string:
        string = "coffee machine"
    if "coffee maker" in string:
        string = "coffee machine"

    if "dishwasher" in string:
        string = "dish washer"
    if "air conditioner" in string:
        string = "ac"

    if "air conditioning" in string:
        string = "ac"
    
    string = re.sub(' +', ' ', string)
    string = re.sub(r'\d+', '', string)
    return string.strip()

# %% [markdown]
# ### Get device list

# %%
device_list = []
ignore_list = [
    'CE appliance'
    ' kettle/toaster',
    ' dehumidifier/heater',
    'HairDryer-Straightener',
    'Office Desk',
    'heat basement',
    'set top box',
    'subpanel',




]
path = "./Energy_graph/data/training_data/"
for file in tqdm(os.listdir(path)):
    if not file.endswith(".pkl"):
        continue
   
    print(file)
    data = pd.read_pickle(path + file)
    for house in data:
        
        for device in data[house]:
            device_org = device
            device = device.lower()
            if device == "aggregate" or "outlet" in device or "sockets" in device or "lamp" in device or "light" in device or "plug" in device or "appliance" in device:
                # print("2 IGNORED: ", house, device)
                continue
  
            if house == "REFIT_21":
                if "kettle" in device or "toaster" in device:
                    print("1 IGNORED: ", house, device)
                    continue
            skip = False
            for d in ignore_list:
                if d.strip().lower() in device_org.strip().lower():
                    skip = True
                    break
            if skip:
                print("2 IGNORED: ", house, device)
                continue
            device = preprocess_string(device)
            test = device
            if "lamp" in device:
                print("HERE: ",house, device , test)
            if device not in device_list:
                device_list.append((device_org, device))


device_list = list(set(device_list))

# # save to pickle 
# import pickle
# with open('./Energy_graph/device_list.pkl', 'wb') as f:
#     pickle.dump(device_list, f)
# Out:
#   8%|▊         | 1/13 [00:00<00:01,  6.57it/s]
# REDD.pkl
# 2 IGNORED:  REDD_5 subpanel
# ECO.pkl
#  15%|█▌        | 2/13 [00:04<00:25,  2.34s/it]
# REFIT.pkl
#  23%|██▎       | 3/13 [00:07<00:28,  2.86s/it]
# 1 IGNORED:  REFIT_21  kettle/toaster
# 2 IGNORED:  REFIT_16  dehumidifier/heater
# UK-DALE.pkl
#  31%|███       | 4/13 [00:10<00:27,  3.07s/it]
# 2 IGNORED:  UKDALE_5 set top box
# SUST2.pkl
#  38%|███▊      | 5/13 [00:11<00:16,  2.12s/it]
# 2 IGNORED:  SUST2_1 hairdryer-straightener
# ENERTALK.pkl
#  54%|█████▍    | 7/13 [00:14<00:11,  1.86s/it]
# HES_clean.pkl
#  62%|██████▏   | 8/13 [00:14<00:07,  1.44s/it]
# DEDDIAG.pkl
#  69%|██████▉   | 9/13 [00:16<00:05,  1.37s/it]
# 2 IGNORED:  DEDDIAG_8 office desk
# HEART.pkl
#  77%|███████▋  | 10/13 [00:16<00:03,  1.15s/it]
# IAWE.pkl
# DRED.pkl
# 100%|██████████| 13/13 [00:17<00:00,  1.31s/it]

# %%
device_list.sort()
device_list
# Out:
# [(' blender', 'blender'),
#  (' bread-maker', 'bread maker'),
#  (' chest freezer', 'chest freezer'),
#  (' chest freezer (in garage)', 'chest freezer'),
#  (' combination microwave', 'combination microwave'),
#  (' computer', 'pc'),
#  (' computer site', 'pc'),
#  (' desktop computer', 'pc'),
#  (' dishwasher', 'dish washer'),
#  (' dryer', 'dryer'),
#  (' electric heater', 'electric heater'),
#  (' electric heater (1)?', 'electric heater'),
#  (' electric heater (2)', 'electric heater'),
#  (' food mixer', 'food mixer'),
#  (' food processor', 'food processor'),
#  (' freezer', 'freezer'),
#  (' freezer (garage)', 'freezer'),
#  (' freezer (utility room)', 'freezer'),
#  (' freezer(garage)', 'freezer'),
#  (' fridge', 'fridge'),
#  (' fridge & freezer', 'fridge freezer'),
#  (' fridge(garage)', 'fridge'),
#  (' fridge-freezer', 'fridge freezer'),
#  (' fridge-freezer (1)', 'fridge freezer'),
#  (' fridge-freezer (2)', 'fridge freezer'),
#  (' hi-fi', 'audio system'),
#  (' kettle', 'kettle'),
#  (' microwave', 'microwave'),
#  (' mjy computer', 'pc'),
#  (' oven extractor fan', 'oven extractor fan'),
#  (' pgm computer', 'pc'),
#  (' pond pump', 'pond pump'),
#  (' router', 'router'),
#  (' television', 'television'),
#  (' television site', 'television'),
#  (' television site (bedroom)', 'television'),
#  (' television site(lounge)', 'television'),
#  (' television site2', 'television'),
#  (' toaster', 'toaster'),
#  (' tumble dryer', 'tumble dryer'),
#  (' tumble dryer (garage)', 'tumble dryer'),
#  (' tumble dryer 3', 'tumble dryer'),
#  (' upright freezer', 'upright freezer'),
#  (' vivarium', 'vivarium'),
#  (' washer dryer', 'washer dryer'),
#  (' washer dryer(garage)', 'washer dryer'),
#  (' washing machine', 'washing machine'),
#  (' washing machine (1)', 'washing machine'),
#  (' washing machine (2)', 'washing machine'),
#  ('Air exhaust', 'air exhaust'),
#  ('Coffee Machine', 'coffee machine'),
#  ('Coffee machine', 'coffee machine'),
#  ('CoffeeMachine', 'coffee machine'),
#  ('Dish Washer', 'dish washer'),
#  ('Dishwasher', 'dish washer'),
#  ('Dryer', 'dryer'),
#  ('Fountain', 'fountain'),
#  ('Freezer', 'freezer'),
#  ('Fridge', 'fridge'),
#  ('Fridge-Freezer', 'fridge freezer'),
#  ('HTPC', 'htpc'),
#  ('HandMixer', 'handmixer'),
#  ('Kettle', 'kettle'),
#  ('Laptop', 'laptop'),
#  ('Laptops', 'laptop'),
#  ('MacBook2007', 'laptop'),
#  ('MacBookPro2011-1', 'laptop'),
#  ('MacBookPro2011-2', 'laptop'),
#  ('Microwave', 'microwave'),
#  ('PC', 'pc'),
#  ('Refrigerator', 'fridge'),
#  ('Router', 'router'),
#  ('Stereo', 'stereo'),
#  ('Stove', 'stove'),
#  ('Stove-Oven', 'stove oven'),
#  ('TV', 'television'),
#  ('TV-Grundig', 'television'),
#  ('TV-LG', 'television'),
#  ('TV-Philips', 'television'),
#  ('TV-Samsung', 'television'),
#  ('TV-Sharp', 'television'),
#  ('Tablet', 'tablet'),
#  ('Toaster', 'toaster'),
#  ('USB hub', 'usb hub'),
#  ('VaccumCleaner', 'vacuum cleaner'),
#  ('Washing Machine', 'washing machine'),
#  ('Washing machine', 'washing machine'),
#  ('active speaker', 'speaker'),
#  ('active subwoofer', 'speaker'),
#  ('air conditioner', 'ac'),
#  ('air conditioning', 'ac'),
#  ('air exchanger', 'air exchanger'),
#  ('air handling unit', 'air handling unit'),
#  ('audio amplifier', 'audio amplifier'),
#  ('audio system', 'audio system'),
#  ('baby monitor', 'baby monitor'),
#  ('basement bathroom', 'basement bathroom'),
#  ('boiler', 'boiler'),
#  ('bouncy castle pump', 'bouncy castle pump'),
#  ('breadmaker', 'bread maker'),
#  ('broadband router', 'router'),
#  ('car charger', 'ev'),
#  ('charger', 'charger'),
#  ('clothes iron', 'iron'),
#  ('coffee maker', 'coffee machine'),
#  ('computer', 'pc'),
#  ('computer monitor', 'monitor'),
#  ('cooker', 'cooker'),
#  ('desktop computer', 'pc'),
#  ('dish washer', 'dish washer'),
#  ('dishwasher', 'dish washer'),
#  ('dryer', 'dryer'),
#  ('electric furnace', 'electric furnace'),
#  ('electric heating element', 'electric heating element'),
#  ('electric oven', 'electric oven'),
#  ('electric space heater', 'electric space heater'),
#  ('electric stove', 'electric stove'),
#  ('external hard disk', 'external hard disk'),
#  ('fan', 'fan'),
#  ('food processor', 'food processor'),
#  ('fridge', 'fridge'),
#  ('fridge freezer', 'fridge freezer'),
#  ('games console', 'games console'),
#  ('gaming PC', 'gaming pc'),
#  ('hair dryer', 'hair dryer'),
#  ('hair straighteners', 'hair straighteners'),
#  ('heater', 'heater'),
#  ('iron', 'iron'),
#  ('kettle', 'kettle'),
#  ('kimchi-fridge', 'kimchi fridge'),
#  ('laptop', 'laptop'),
#  ('laptop computer', 'laptop'),
#  ('microwave', 'microwave'),
#  ('minioven', 'minioven'),
#  ('mobile phone charger', 'mobile phone charger'),
#  ('modem', 'router'),
#  ('monitor', 'monitor'),
#  ('motor', 'motor'),
#  ('network attached storage', 'network attached storage'),
#  ('oven', 'oven'),
#  ('printer', 'printer'),
#  ('projector', 'projector'),
#  ('radio', 'radio'),
#  ('rice cooker', 'rice cooker'),
#  ('rice-cooker', 'rice cooker'),
#  ('router', 'router'),
#  ('running machine', 'running machine'),
#  ('server computer', 'server'),
#  ('smoke alarm', 'smoke alarm'),
#  ('solar thermal pumping station', 'solar thermal pumping station'),
#  ('soldering iron', 'soldering iron'),
#  ('tablet computer charger', 'tablet computer charger'),
#  ('television', 'television'),
#  ('toasted sandwich maker', 'toaster'),
#  ('toaster', 'toaster'),
#  ('towel dryer', 'towel dryer'),
#  ('treadmill', 'running machine'),
#  ('vacuum cleaner', 'vacuum cleaner'),
#  ('washer dryer', 'washer dryer'),
#  ('washing machine', 'washing machine'),
#  ('washing-machine', 'washing machine'),
#  ('waste disposal unit', 'waste disposal unit'),
#  ('water-purifier', 'water purifier'),
#  ('watercooker', 'watercooker'),
#  ('whirlpool bath', 'whirlpool bath')]

# %%
device_list = pd.read_pickle('./Energy_graph/embeddings/device_list.pkl')

# %% [markdown]
# ### Fuzzy wuzzy

# %%
labels = device_list
grouped_labels = {}
threshold = 86 # Set a threshold for similarity

for label in labels:
    found = False
    for key in grouped_labels:
        if fuzz.WRatio(label.lower(), key.lower()) > threshold:
            grouped_labels[key].append(label)
            found = True
            break
    if not found:
        grouped_labels[label] = [label]

# grouped_labels["fridge"].append("refrigerator")
# grouped_labels.pop("refrigerator")
grouped_labels, len(grouped_labels)
# Out:
# ({'car charger': ['car charger', 'charger'],
#   'bread maker': ['bread maker'],
#   'blender': ['blender'],
#   'hairdryer straightener': ['hairdryer straightener', 'dryer'],
#   'vacuum cleaner': ['vacuum cleaner'],
#   'rice cooker': ['rice cooker', 'cooker'],
#   'water heater': ['water heater', 'heater'],
#   'heat bedroom': ['heat bedroom'],
#   'ce appliance': ['ce appliance', 'wet appliance'],
#   'smoke alarm': ['smoke alarm'],
#   'electric heater': ['electric heater', 'electric space heater'],
#   'minioven': ['minioven', 'oven'],
#   'air handling unit': ['air handling unit'],
#   'washing machine': ['washing machine'],
#   'chest freezer': ['chest freezer', 'freezer'],
#   'heat living room': ['heat living room', 'heat dining room'],
#   'waste disposal unit': ['waste disposal unit'],
#   'water purifier': ['water purifier'],
#   'air conditioning': ['air conditioning'],
#   'motor': ['motor'],
#   'laptop': ['laptop', 'laptops'],
#   'games console': ['games console'],
#   'bouncy castle pump': ['bouncy castle pump'],
#   'food mixer': ['food mixer'],
#   'fountain': ['fountain'],
#   'stove': ['stove', 'stove oven', 'electric stove'],
#   'watercooker': ['watercooker'],
#   'router': ['router', 'broadband router'],
#   'coffee machine': ['coffee machine', 'coffeemachine'],
#   'tumble dryer': ['tumble dryer', 'tumble dryer 3'],
#   'combination microwave': ['combination microwave', 'microwave'],
#   'office desk': ['office desk'],
#   'electric oven': ['electric oven'],
#   'handmixer': ['handmixer'],
#   'heat basement': ['heat basement'],
#   'towel dryer': ['towel dryer'],
#   'upright freezer': ['upright freezer'],
#   'running machine': ['running machine'],
#   'hi fi': ['hi fi'],
#   'audio system': ['audio system'],
#   'gaming pc': ['gaming pc', 'pc'],
#   'air conditioner': ['air conditioner'],
#   'set top box': ['set top box'],
#   'external hard disk': ['external hard disk'],
#   'usb hub': ['usb hub'],
#   'subpanel': ['subpanel'],
#   'printer': ['printer'],
#   'electric furnace': ['electric furnace'],
#   'vivarium': ['vivarium'],
#   'radio': ['radio'],
#   'network attached storage': ['network attached storage'],
#   'fan': ['fan', 'oven extractor fan'],
#   'tablet': ['tablet'],
#   'pond pump': ['pond pump'],
#   'speaker': ['speaker'],
#   'electric heating element': ['electric heating element'],
#   'treadmill': ['treadmill'],
#   'boiler': ['boiler'],
#   'baby monitor': ['baby monitor', 'monitor'],
#   'mobile phone charger': ['mobile phone charger'],
#   'fridge': ['fridge', 'fridge freezer', 'kimchi fridge'],
#   'food processor': ['food processor'],
#   'coffee maker': ['coffee maker'],
#   'heat kitchen': ['heat kitchen'],
#   'kettle': ['kettle'],
#   'stereo': ['stereo'],
#   'projector': ['projector'],
#   'htpc': ['htpc'],
#   'washer dryer': ['washer dryer'],
#   'whirlpool bath': ['whirlpool bath'],
#   'heat garage': ['heat garage'],
#   'solar thermal pumping station': ['solar thermal pumping station'],
#   'iron': ['iron'],
#   'hair dryer': ['hair dryer'],
#   'toaster': ['toaster'],
#   'television': ['television'],
#   'audio amplifier': ['audio amplifier'],
#   'dish washer': ['dish washer', 'dishwasher'],
#   'air exchanger': ['air exchanger'],
#   'air exhaust': ['air exhaust'],
#   'hair straighteners': ['hair straighteners']},
#  81)

# %%
str1 = "fridge"
str2 = "refrigerator"
fuzz.partial_ratio(str1, str2), fuzz.ratio(str1,str2), fuzz.token_sort_ratio(str1,str2), fuzz.token_set_ratio(str1,str2), fuzz.WRatio(str1,str2)
# Out:
# (83, 56, 56, 56, 75)

# %% [markdown]
# ### Spacy using kmeans

# %%
import spacy
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt

N_CLUSTERS = 25

# Load the largge English model in spaCy (contains word vectors)
# nlp = spacy.load('en_core_web_trf')
nlp = spacy.load('en_core_web_lg')

# List of devices
devices = device_list

# Create vectors for each device name
device_vectors = np.array([nlp(device).vector for device in devices])

# Use KMeans clustering to group devices
kmeans = KMeans(n_clusters=N_CLUSTERS)  # Choose an appropriate number of clusters
kmeans.fit(device_vectors)
labels = kmeans.labels_

# Print out the devices grouped by their cluster
grouped_devices = {}
for label, device in zip(labels, devices):
    if label not in grouped_devices:
        grouped_devices[label] = []
    grouped_devices[label].append(device)

for label, devices in grouped_devices.items():
    print(f"Group {label}: {devices}")
# Out:
# Group 1: ['coffeemachine', 'htpc', 'handmixer', 'breadmaker', 'vivarium', 'television', 'fountain', 'minioven', 'vaccumcleaner', 'subpanel', 'watercooker']
# Group 13: ['food mixer', 'food processor']
# Group 2: ['electric oven', 'oven', 'stove oven', 'stove', 'boiler']
# Group 7: ['games console', 'router', 'usb hub', 'printer', 'broadband router', 'network attached storage', 'projector']
# Group 21: ['electric stove', 'electric heating element', 'electric heater ', 'electric heater', 'solar thermal pumping station', 'motor', 'electric space heater', 'electric furnace', 'heater']
# Group 12: ['refrigerator', 'fridge freezer', 'kimchi fridge', 'freezer', 'fridge', 'chest freezer ', 'chest freezer', 'fridge freezer ', 'upright freezer', 'freezer ']
# Group 23: ['stereo', 'audio system', 'audio amplifier', 'speaker']
# Group 4: ['treadmill', 'bouncy castle pump', 'whirlpool bath', 'office desk', 'combination microwave', 'ce appliance', 'hairdryer straightener', 'external hard disk', 'smoke alarm']
# Group 5: ['air conditioner', 'air conditioning', 'air exhaust', 'air exchanger', 'air handling unit']
# Group 24: ['hair straighteners', 'hair dryer']
# Group 14: ['water purifier', 'pond pump', 'water heater']
# Group 11: ['tumble dryer', 'dishwasher', 'tumble dryer ', 'dryer', 'vacuum cleaner', 'towel dryer', 'washer dryer']
# Group 0: ['heat kitchen', 'heat basement', 'heat garage', 'heat dining room', 'heat living room']
# Group 8: ['heat bedroom #3', 'heat bedroom #2', 'heat bedroom #1', 'tumble dryer 3']
# Group 22: ['washing machine ', 'coffee machine', 'running machine', 'washing machine', 'waste disposal unit', 'wet appliance']
# Group 3: ['microwave', 'cooker', 'coffee maker', 'blender', 'dish washer', 'oven extractor fan', 'rice cooker', 'toaster', 'kettle', 'bread maker']
# Group 10: ['hi fi']
# Group 20: ['charger', 'laptops', 'mobile phone charger', 'tablet', 'car charger', 'laptop']
# Group 16: ['set top box']
# Group 9: ['fan']
# Group 19: ['baby monitor', 'monitor']
# Group 6: ['gaming pc', 'pc']
# Group 15: ['radio']
# Group 18: ['iron']
# Group 17: ['dehumidifier/heater']

# %%
# Apply PCA to reduce dimensions to 2
pca = PCA(n_components=2)
reduced_device_vectors = pca.fit_transform(device_vectors)

# Plot the reduced device vectors
plt.figure(figsize=(10, 6))
plt.scatter(reduced_device_vectors[:, 0], reduced_device_vectors[:, 1])

# Annotate the points
for i, device in enumerate(devices):
    plt.annotate(device, (reduced_device_vectors[i, 0], reduced_device_vectors[i, 1]))

plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Device Vectors')
plt.show()

# %%
import spacy
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt

# Load the large English model in spaCy (contains word vectors)
# nlp = spacy.load('en_core_web_trf')
nlp = spacy.load('en_core_web_lg')

# List of devices
devices = device_list  # Assuming device_list is already defined

# Create vectors for each device name
device_vectors = np.array([nlp(device).vector for device in devices])

# Loop through different numbers of clusters
for n_clusters in range(25, 76, 5):
    # Initialize and fit KMeans algorithm
    kmeans = KMeans(n_clusters=n_clusters)
    kmeans.fit(device_vectors)
    labels = kmeans.labels_
    
    # Group the devices based on their cluster label
    grouped_devices = {}
    for label, device in zip(labels, devices):
        if label not in grouped_devices:
            grouped_devices[label] = []
        grouped_devices[label].append(device)
    
    # Print and plot the device groups
    print(f"KMeans with {n_clusters} Clusters")
    plt.figure(figsize=(10, 6))
    
    for label, devices in grouped_devices.items():
        print(f"Group {label}: {devices}")
        
        # Assuming device_vectors is 2D. If not, you might want to reduce dimensionality before plotting
        plt.scatter(device_vectors[labels == label, 0], device_vectors[labels == label, 1], label=f'Group {label}')
        
    plt.legend()
    plt.title(f"KMeans Clustering with {n_clusters} Clusters")
    plt.show()
# Out:
# KMeans with 25 Clusters
# Group 5: ['coffeemachine', 'htpc', 'handmixer', 'breadmaker', 'vivarium', 'fountain', 'minioven', 'vaccumcleaner', 'subpanel', 'watercooker']
# Group 17: ['food mixer', 'food processor']
# Group 15: ['electric oven', 'oven', 'stove oven', 'oven extractor fan', 'stove']
# Group 2: ['games console', 'router', 'combination microwave', 'charger', 'usb hub', 'printer', 'broadband router', 'waste disposal unit', 'external hard disk', 'monitor', 'network attached storage', 'projector']
# Group 6: ['electric stove', 'electric heating element', 'electric heater ', 'electric heater', 'solar thermal pumping station', 'electric space heater', 'electric furnace', 'heater', 'dehumidifier/heater', 'boiler']
# Group 3: ['refrigerator', 'fridge freezer', 'kimchi fridge', 'freezer', 'microwave', 'fridge', 'chest freezer ', 'chest freezer', 'fridge freezer ', 'upright freezer', 'freezer ']
# Group 22: ['stereo', 'audio system', 'audio amplifier', 'speaker']
# Group 11: ['treadmill', 'bouncy castle pump', 'hair straighteners', 'whirlpool bath', 'ce appliance', 'dishwasher', 'blender', 'baby monitor', 'hairdryer straightener', 'vacuum cleaner', 'toaster', 'kettle', 'smoke alarm']
# Group 8: ['air conditioner', 'air conditioning', 'air exhaust', 'air exchanger', 'air handling unit']
# Group 24: ['water purifier', 'pond pump', 'water heater']
# Group 7: ['tumble dryer', 'tumble dryer ', 'dryer', 'hair dryer', 'towel dryer', 'washer dryer']
# Group 13: ['heat kitchen', 'heat basement', 'heat garage', 'heat dining room', 'heat living room']
# Group 21: ['heat bedroom #3', 'heat bedroom #2', 'heat bedroom #1']
# Group 23: ['washing machine ', 'running machine', 'washing machine', 'wet appliance']
# Group 9: ['office desk', 'laptops', 'mobile phone charger', 'tablet', 'laptop']
# Group 12: ['hi fi']
# Group 20: ['cooker', 'dish washer', 'rice cooker']
# Group 16: ['coffee maker', 'coffee machine', 'bread maker']
# Group 18: ['set top box']
# Group 10: ['fan']
# Group 1: ['television', 'radio']
# Group 4: ['gaming pc', 'pc']
# Group 19: ['motor', 'car charger']
# Group 14: ['iron']
# Group 0: ['tumble dryer 3']
# KMeans with 30 Clusters
# Group 1: ['tumble dryer 3']
# KMeans with 35 Clusters
# Group 14: ['tumble dryer 3']
# KMeans with 40 Clusters
# Group 6: ['tumble dryer 3']
# KMeans with 45 Clusters
# Group 12: ['tumble dryer 3']
# KMeans with 50 Clusters
# Group 0: ['tumble dryer 3']
# KMeans with 55 Clusters
# Group 15: ['tumble dryer 3']
# KMeans with 60 Clusters
# Group 7: ['tumble dryer 3']
# KMeans with 65 Clusters
# Group 2: ['tumble dryer 3']
# KMeans with 70 Clusters
# Group 4: ['tumble dryer 3']
# KMeans with 75 Clusters
# Group 4: ['tumble dryer 3']

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt
import numpy as np

# Given that 'device_vectors' is a 2D numpy array where each row is a vector for a corresponding device
device_vectors = np.array(device_vectors)  

# Generate the linkage matrix
Z = linkage(device_vectors, 'ward')

# Create a dendrogram
dendrogram(
    Z,
    labels=device_list,
    leaf_rotation=90.,
    leaf_font_size=12.,
)

plt.title('Hierarchical Clustering Dendrogram')
plt.show()

# %%
from scipy.cluster.hierarchy import fcluster

# Cut the dendrogram to create clusters (e.g., cut at height 20)
max_height = 50
clusters = fcluster(Z, max_height, criterion='distance')

# Create dictionary to store clusters
cluster_dict = {}
for i, cluster_id in enumerate(clusters):
    if cluster_id not in cluster_dict:
        cluster_dict[cluster_id] = []
    cluster_dict[cluster_id].append(device_list[i])

# Print clusters
for cluster_id, devices in cluster_dict.items():
    print(f"Group {cluster_id}: {devices}")
# Out:
# Group 1: ['coffeemachine', 'htpc', 'handmixer', 'vivarium', 'minioven', 'vaccumcleaner', 'subpanel', 'watercooker']
# Group 27: ['food mixer', 'food processor']
# Group 21: ['electric oven', 'electric stove', 'electric heater ', 'electric heater', 'electric space heater', 'electric furnace', 'heater', 'boiler']
# Group 5: ['games console']
# Group 28: ['refrigerator', 'treadmill', 'microwave', 'combination microwave', 'dishwasher', 'blender', 'breadmaker', 'hairdryer straightener', 'oven extractor fan', 'vacuum cleaner', 'toaster', 'kettle', 'wet appliance']
# Group 4: ['stereo', 'audio system', 'audio amplifier', 'speaker']
# Group 18: ['air conditioner', 'air conditioning', 'air exhaust', 'air exchanger', 'air handling unit']
# Group 23: ['bouncy castle pump', 'whirlpool bath', 'pond pump', 'fountain']
# Group 13: ['electric heating element', 'solar thermal pumping station', 'printer', 'waste disposal unit', 'external hard disk', 'network attached storage', 'projector']
# Group 25: ['hair straighteners', 'hair dryer']
# Group 33: ['oven', 'stove oven', 'stove']
# Group 22: ['water purifier', 'water heater']
# Group 26: ['tumble dryer', 'tumble dryer ', 'dryer', 'towel dryer', 'washer dryer']
# Group 20: ['heat kitchen', 'heat basement', 'heat garage', 'heat dining room', 'heat living room']
# Group 19: ['heat bedroom #3', 'heat bedroom #2', 'heat bedroom #1', 'tumble dryer 3']
# Group 31: ['fridge freezer', 'kimchi fridge', 'freezer', 'fridge', 'chest freezer ', 'chest freezer', 'fridge freezer ', 'upright freezer', 'freezer ']
# Group 14: ['router', 'broadband router']
# Group 30: ['washing machine ', 'coffee machine', 'running machine', 'washing machine']
# Group 7: ['office desk']
# Group 17: ['hi fi']
# Group 9: ['charger', 'mobile phone charger', 'car charger']
# Group 15: ['usb hub']
# Group 11: ['ce appliance']
# Group 32: ['cooker', 'dish washer', 'rice cooker']
# Group 6: ['laptops', 'tablet', 'laptop']
# Group 29: ['coffee maker', 'bread maker']
# Group 8: ['set top box']
# Group 34: ['fan']
# Group 3: ['television', 'radio']
# Group 2: ['baby monitor', 'smoke alarm', 'monitor']
# Group 16: ['gaming pc', 'pc']
# Group 10: ['motor']
# Group 24: ['iron']
# Group 12: ['dehumidifier/heater']

# %% [markdown]
# ### Spacy using kmeans using transformer

# %%
import spacy
from sklearn.cluster import KMeans
import numpy as np

# Initialize spaCy model with transformer
nlp = spacy.load("en_core_web_trf")

# Add the transformer component to the pipeline
if "transformer" not in nlp.pipe_names:
    transformer = nlp.add_pipe("transformer", name="transformer", last=True)

# Get vectors from transformer output
def get_vector_from_transformer_output(doc):
    tensor = doc._.trf_data.tensors[-1]
    return tensor.mean(axis=1).squeeze()

# Your list of devices
# device_list = ["laptop", "mobile", "tablet", "desktop"]

# Generate vectors
device_vectors = np.array([get_vector_from_transformer_output(nlp(device)) for device in device_list])


# KMeans clustering
# N_CLUSTERS = 2  # or however many clusters you'd like
kmeans = KMeans(n_clusters=N_CLUSTERS)
kmeans.fit(device_vectors.reshape(-1, 1))
labels = kmeans.labels_

# Group by labels
grouped_devices = {i: [] for i in set(labels)}
for label, device in zip(labels, device_list):
    grouped_devices[label].append(device)

# Display the groups
for label, devices in grouped_devices.items():
    print(f"Group {label}: {devices}")
# Out:
# Group 0: ['motor', 'air handling unit', 'smoke alarm', 'fridge freezer', 'blender', 'projector', 'car charger', 'air conditioning', 'set top box', 'fridge freezer ', 'bread maker']
# Group 1: ['broadband router', 'dehumidifier/heater', 'gaming pc']
# Group 2: ['solar thermal pumping station', 'tumble dryer ', 'tumble dryer']
# Group 3: ['minioven', 'vivarium', 'heat kitchen']
# Group 4: ['tablet', 'stereo', 'dish washer', 'handmixer']
# Group 5: ['upright freezer', 'freezer', 'baby monitor', 'pc', 'electric furnace', 'freezer ', 'stove']
# Group 6: ['fridge', 'waste disposal unit', 'charger', 'speaker', 'running machine', 'heat dining room', 'combination microwave', 'coffee machine', 'electric space heater', 'vacuum cleaner', 'pond pump', 'radio']
# Group 7: ['wet appliance', 'microwave', 'audio amplifier', 'air conditioner', 'oven extractor fan', 'food mixer', 'watercooker']
# Group 8: ['chest freezer ', 'washing machine', 'breadmaker', 'kimchi fridge', 'washing machine ', 'printer', 'coffeemachine', 'chest freezer', 'hair dryer', 'office desk', 'cooker']
# Group 9: ['router', 'external hard disk']
# Group 10: ['toaster', 'fan']
# Group 11: ['electric heating element', 'television', 'whirlpool bath', 'games console', 'audio system', 'air exchanger', 'water purifier', 'network attached storage', 'refrigerator']
# Group 12: ['usb hub', 'hair straighteners']
# Group 13: ['rice cooker', 'electric heater', 'electric heater ', 'coffee maker', 'heat basement', 'air exhaust', 'mobile phone charger', 'food processor', 'heater', 'heat living room', 'heat bedroom #2', 'fountain', 'heat bedroom #3', 'electric stove']
# Group 14: ['dishwasher', 'subpanel', 'hairdryer straightener', 'boiler', 'ce appliance']
# Group 15: ['tumble dryer 3', 'electric oven', 'iron', 'stove oven', 'treadmill']
# Group 16: ['heat bedroom #1', 'bouncy castle pump', 'water heater', 'hi fi', 'kettle', 'htpc']
# Group 17: ['vaccumcleaner', 'washer dryer', 'oven']
# Group 18: ['laptops', 'laptop']
# Group 19: ['heat garage', 'towel dryer', 'dryer', 'monitor']

# %% [markdown]
# ### Genism k-means using google news word2vec

# %%
from nltk.stem import PorterStemmer
from gensim.models import KeyedVectors

# Initialize stemmer
ps = PorterStemmer()

# Load Word2Vec model
model_path = "./Energy_graph/google_word2vec/GoogleNews-vectors-negative300.bin"  # Replace with the path to your model
model = KeyedVectors.load_word2vec_format(model_path, binary=True)

# Your list of words
words = device_list  # Replace with your list

# Stem words and find vectors
for word in words:
    stemmed_word = ps.stem(word)
    try:
        vector = model[stemmed_word]
        print(f"Vector for {word} (stemmed to {stemmed_word})")
    except KeyError:
        print(f"{word} (stemmed to {stemmed_word}) not in vocabulary.")
# Out:
# coffeemachine (stemmed to coffeemachin) not in vocabulary.
# food mixer (stemmed to food mix) not in vocabulary.
# electric oven (stemmed to electric oven) not in vocabulary.
# games console (stemmed to games consol) not in vocabulary.
# electric stove (stemmed to electric stov) not in vocabulary.
# refrigerator (stemmed to refriger) not in vocabulary.
# Vector for stereo (stemmed to stereo)
# treadmill (stemmed to treadmil) not in vocabulary.
# air conditioner (stemmed to air condition) not in vocabulary.
# bouncy castle pump (stemmed to bouncy castle pump) not in vocabulary.
# electric heating element (stemmed to electric heating el) not in vocabulary.
# food processor (stemmed to food processor) not in vocabulary.
# hair straighteners (stemmed to hair straighten) not in vocabulary.
# Vector for oven (stemmed to oven)
# water purifier (stemmed to water purifi) not in vocabulary.
# audio system (stemmed to audio system) not in vocabulary.
# tumble dryer (stemmed to tumble dry) not in vocabulary.
# heat kitchen (stemmed to heat kitchen) not in vocabulary.
# heat bedroom #3 (stemmed to heat bedroom #3) not in vocabulary.
# electric heater  (stemmed to electric heater ) not in vocabulary.
# fridge freezer (stemmed to fridge freez) not in vocabulary.
# kimchi fridge (stemmed to kimchi fridg) not in vocabulary.
# heat basement (stemmed to heat bas) not in vocabulary.
# Vector for router (stemmed to router)
# washing machine  (stemmed to washing machine ) not in vocabulary.
# heat garage (stemmed to heat garag) not in vocabulary.
# whirlpool bath (stemmed to whirlpool bath) not in vocabulary.
# Vector for freezer (stemmed to freezer)
# office desk (stemmed to office desk) not in vocabulary.
# microwave (stemmed to microwav) not in vocabulary.
# combination microwave (stemmed to combination microwav) not in vocabulary.
# electric heater (stemmed to electric heat) not in vocabulary.
# hi fi (stemmed to hi fi) not in vocabulary.
# solar thermal pumping station (stemmed to solar thermal pumping st) not in vocabulary.
# htpc (stemmed to htpc) not in vocabulary.
# air conditioning (stemmed to air condit) not in vocabulary.
# Vector for charger (stemmed to charger)
# usb hub (stemmed to usb hub) not in vocabulary.
# ce appliance (stemmed to ce appli) not in vocabulary.
# audio amplifier (stemmed to audio amplifi) not in vocabulary.
# fridge (stemmed to fridg) not in vocabulary.
# air exhaust (stemmed to air exhaust) not in vocabulary.
# Vector for cooker (stemmed to cooker)
# Vector for laptops (stemmed to laptop)
# handmixer (stemmed to handmix) not in vocabulary.
# coffee maker (stemmed to coffee mak) not in vocabulary.
# Vector for dishwasher (stemmed to dishwash)
# mobile phone charger (stemmed to mobile phone charg) not in vocabulary.
# heat bedroom #2 (stemmed to heat bedroom #2) not in vocabulary.
# Vector for blender (stemmed to blender)
# tumble dryer  (stemmed to tumble dryer ) not in vocabulary.
# breadmaker (stemmed to breadmak) not in vocabulary.
# set top box (stemmed to set top box) not in vocabulary.
# Vector for fan (stemmed to fan)
# stove oven (stemmed to stove oven) not in vocabulary.
# Vector for vivarium (stemmed to vivarium)
# coffee machine (stemmed to coffee machin) not in vocabulary.
# television (stemmed to televis) not in vocabulary.
# dish washer (stemmed to dish wash) not in vocabulary.
# air exchanger (stemmed to air exchang) not in vocabulary.
# Vector for printer (stemmed to printer)
# baby monitor (stemmed to baby monitor) not in vocabulary.
# running machine (stemmed to running machin) not in vocabulary.
# Vector for tablet (stemmed to tablet)
# hairdryer straightener (stemmed to hairdryer straighten) not in vocabulary.
# Vector for dryer (stemmed to dryer)
# gaming pc (stemmed to gaming pc) not in vocabulary.
# broadband router (stemmed to broadband rout) not in vocabulary.
# chest freezer  (stemmed to chest freezer ) not in vocabulary.
# heat dining room (stemmed to heat dining room) not in vocabulary.
# oven extractor fan (stemmed to oven extractor fan) not in vocabulary.
# hair dryer (stemmed to hair dryer) not in vocabulary.
# Vector for motor (stemmed to motor)
# washing machine (stemmed to washing machin) not in vocabulary.
# pond pump (stemmed to pond pump) not in vocabulary.
# chest freezer (stemmed to chest freez) not in vocabulary.
# rice cooker (stemmed to rice cook) not in vocabulary.
# Vector for fountain (stemmed to fountain)
# fridge freezer  (stemmed to fridge freezer ) not in vocabulary.
# Vector for radio (stemmed to radio)
# heat living room (stemmed to heat living room) not in vocabulary.
# vacuum cleaner (stemmed to vacuum clean) not in vocabulary.
# electric space heater (stemmed to electric space heat) not in vocabulary.
# Vector for pc (stemmed to pc)
# minioven (stemmed to minioven) not in vocabulary.
# vaccumcleaner (stemmed to vaccumclean) not in vocabulary.
# car charger (stemmed to car charg) not in vocabulary.
# waste disposal unit (stemmed to waste disposal unit) not in vocabulary.
# upright freezer (stemmed to upright freez) not in vocabulary.
# air handling unit (stemmed to air handling unit) not in vocabulary.
# Vector for iron (stemmed to iron)
# electric furnace (stemmed to electric furnac) not in vocabulary.
# Vector for toaster (stemmed to toaster)
# Vector for subpanel (stemmed to subpanel)
# water heater (stemmed to water heat) not in vocabulary.
# Vector for stove (stemmed to stove)
# Vector for heater (stemmed to heater)
# watercooker (stemmed to watercook) not in vocabulary.
# kettle (stemmed to kettl) not in vocabulary.
# dehumidifier/heater (stemmed to dehumidifier/heat) not in vocabulary.
# towel dryer (stemmed to towel dry) not in vocabulary.
# external hard disk (stemmed to external hard disk) not in vocabulary.
# smoke alarm (stemmed to smoke alarm) not in vocabulary.
# Vector for monitor (stemmed to monitor)
# network attached storage (stemmed to network attached storag) not in vocabulary.
# heat bedroom #1 (stemmed to heat bedroom #1) not in vocabulary.
# tumble dryer 3 (stemmed to tumble dryer 3) not in vocabulary.
# Vector for laptop (stemmed to laptop)
# Vector for speaker (stemmed to speaker)
# bread maker (stemmed to bread mak) not in vocabulary.
# wet appliance (stemmed to wet appli) not in vocabulary.
# Vector for boiler (stemmed to boiler)
# Vector for projector (stemmed to projector)
# washer dryer (stemmed to washer dry) not in vocabulary.
# freezer  (stemmed to freezer ) not in vocabulary.

# %%
from gensim.models import KeyedVectors
from sklearn.cluster import KMeans
import numpy as np

N_CLUSTERS = 25
# Load pre-trained Word2Vec model
# Replace 'path/to/GoogleNews-vectors-negative300.bin' with the actual path to the pre-trained model
model = KeyedVectors.load_word2vec_format('./Energy_graph/google_word2vec/GoogleNews-vectors-negative300.bin', binary=True)

# List of words to cluster
words = device_list

# Create an array of word vectors
word_vectors = np.array([model[word] for word in words if word in model])

# Check for words not in the model
not_in_model = [word for word in words if word not in model]
if not_in_model:
    print(f"Note: The following words are not in the model: {not_in_model}")

# Perform KMeans clustering
 # You can choose a different number of clusters
kmeans = KMeans(n_clusters=N_CLUSTERS)
kmeans.fit(word_vectors)
labels = kmeans.labels_

# Print out the words grouped by their cluster
grouped_words = {}
for label, word in zip(labels, words):
    if label not in grouped_words:
        grouped_words[label] = []
    grouped_words[label].append(word)

for label, grouped_word in grouped_words.items():
    print(f"Group {label}: {grouped_word}")
# Out:
# Note: The following words are not in the model: ['coffeemachine', 'food mixer', 'electric oven', 'games console', 'electric stove', 'air conditioner', 'bouncy castle pump', 'electric heating element', 'food processor', 'hair straighteners', 'water purifier', 'audio system', 'tumble dryer', 'heat kitchen', 'heat bedroom #3', 'electric heater ', 'fridge freezer', 'kimchi fridge', 'heat basement', 'washing machine ', 'heat garage', 'whirlpool bath', 'office desk', 'combination microwave', 'electric heater', 'hi fi', 'solar thermal pumping station', 'htpc', 'air conditioning', 'usb hub', 'ce appliance', 'audio amplifier', 'air exhaust', 'handmixer', 'coffee maker', 'mobile phone charger', 'heat bedroom #2', 'tumble dryer ', 'set top box', 'stove oven', 'coffee machine', 'dish washer', 'air exchanger', 'baby monitor', 'running machine', 'hairdryer straightener', 'gaming pc', 'broadband router', 'chest freezer ', 'heat dining room', 'oven extractor fan', 'hair dryer', 'washing machine', 'pond pump', 'chest freezer', 'rice cooker', 'fridge freezer ', 'heat living room', 'vacuum cleaner', 'electric space heater', 'minioven', 'vaccumcleaner', 'car charger', 'waste disposal unit', 'upright freezer', 'air handling unit', 'electric furnace', 'water heater', 'watercooker', 'dehumidifier/heater', 'towel dryer', 'external hard disk', 'smoke alarm', 'network attached storage', 'heat bedroom #1', 'tumble dryer 3', 'bread maker', 'wet appliance', 'washer dryer', 'freezer ']
# Group 4: ['coffeemachine', 'refrigerator', 'air conditioner']
# Group 15: ['food mixer']
# Group 5: ['electric oven']
# Group 10: ['games console', 'bouncy castle pump', 'freezer', 'office desk']
# Group 1: ['electric stove']
# Group 18: ['stereo']
# Group 8: ['treadmill']
# Group 7: ['electric heating element', 'electric heater']
# Group 0: ['food processor', 'electric heater ']
# Group 13: ['hair straighteners']
# Group 24: ['oven', 'heat garage']
# Group 19: ['water purifier']
# Group 12: ['audio system']
# Group 2: ['tumble dryer', 'fridge freezer', 'heat basement']
# Group 3: ['heat kitchen']
# Group 22: ['heat bedroom #3']
# Group 11: ['kimchi fridge']
# Group 9: ['router']
# Group 6: ['washing machine ']
# Group 16: ['whirlpool bath']
# Group 14: ['microwave']
# Group 20: ['combination microwave']
# Group 21: ['hi fi']
# Group 23: ['solar thermal pumping station']
# Group 17: ['htpc']
