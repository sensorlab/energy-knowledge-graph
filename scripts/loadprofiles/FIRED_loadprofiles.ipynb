# %%
# %pip install av

import pandas as pd

from Energy_graph.data import helper as hp
# Out:
# ...
#   Using cached av-10.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31.0 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %ls
# Out:
# datasets/  Energy_graph/  shared/  Untitled.ipynb

# %%
hp.FIRED_BASE_FOLDER = "Energy_graph/data/FIRED/"

# %%
smartmeter = hp.()
smartmeter
# Out:
# {'sewing machine': {'brand': 'Pfaff',
#   'model': 'hobbymatic 919',
#   'room': 'Livingroom',
#   'powerRating': 80.0,
#   'phase': 3},
#  'vacuum cleaner': {'brand': 'FAKIR',
#   'model': 'S2200 electronic',
#   'room': 'Livingroom',
#   'powerRating': 1300.0,
#   'phase': 3},
#  'iron': {'brand': 'Philips',
#   'model': 'azur EXCEL PLUS 525',
#   'room': 'Livingroom',
#   'powerRating': 1960.0,
#   'phase': 3},
#  'airbed': {'brand': 'NONAME',
#   'model': 'HT-638',
#   'room': 'Livingroom',
#   'powerRating': 130.0,
#   'phase': 3},
#  'battery charger': {'brand': 'SANYO',
#   'model': 'MQN04',
#   'room': 'Livingroom',
#   'powerRating': 5.0,
#   'phase': 3},
#  'toothbrush': {'brand': 'ORAL-B',
#   'model': 'Vitality Cross Action D12.513',
#   'room': 'Livingroom',
#   'powerRating': 5.0,
#   'phase': 3},
#  'razor': {'brand': 'Philips',
#   'model': 'SensoTouch Series 7000',
#   'room': 'Livingroom',
#   'powerRating': 5.4,
#   'phase': 3},
# ...
