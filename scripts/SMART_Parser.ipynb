# %%
import pandas as pd
import os

# %%
SMART = pd.read_csv("../data/SMART/HomeC.csv")
# Out:
# C:\Users\foglo\AppData\Local\Temp\ipykernel_21524\2492613404.py:1: DtypeWarning: Columns (0,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   SMART = pd.read_csv("../data/SMART/HomeC.csv")

# %%
SMART.drop(['temperature', 'icon', 'humidity', 'visibility', 'summary', 
              'apparentTemperature', 'pressure', 'windSpeed', 'cloudCover', 
              'windBearing', 'precipIntensity', 'dewPoint', 'precipProbability'], 
             axis=1, inplace=True)

# %%
SMART.head(100000000000000)
# Out:
#            time  use [kW]  gen [kW]  House overall [kW]  Dishwasher [kW]  \
# 0    1451624400  0.932833  0.003483            0.932833         0.000033
# 1    1451624401  0.934333  0.003467            0.934333         0.000000
# 2    1451624402  0.931817  0.003467            0.931817         0.000017
# 3    1451624403  1.022050  0.003483            1.022050         0.000017
# 4    1451624404  1.139400  0.003467            1.139400         0.000133
# ..          ...       ...       ...                 ...              ...
# 995  1451625395  1.585867  0.003467            1.585867         0.000233
# 996  1451625396  1.561733  0.003450            1.561733         0.000233
# 997  1451625397  1.588117  0.003433            1.588117         0.000217
# 998  1451625398  1.563850  0.003467            1.563850         0.000233
# 999  1451625399  1.562683  0.003467            1.562683         0.000233
#
#      Furnace 1 [kW]  Furnace 2 [kW]  Home office [kW]  Fridge [kW]  \
# ...
